# %% [markdown]
# <h1 style="text-align:center;">Song Success Prediction Model</h1>
# <h2 style="text-align:center;">Data Wrangling & EDA</h2>
#
# <h4 style="text-align:center;">by Cameron Hicks</h3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import requests
import time
from urllib.parse import quote
from sklearn.preprocessing import MultiLabelBinarizer
from scipy.stats import chi2_contingency
from scipy.stats import pointbiserialr

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Spotify Data

# %% [markdown]
# ### Import Data
#
# Spotify Analytics Dataset imported into a DataFrame titled "raw_data".
#
# Data Source: https://www.kaggle.com/datasets/rohiteng/spotify-music-analytics-dataset-20152025?resource=download

# %%
raw_data = pd.read_csv('../../Data/spotify_2015_2025_85k.csv')

# %% [markdown]
# ### Inspect Spotify Data
#
# Before making any changes to the data it needs to be inspected. In the cells below I fully inspect the data to become familiar with it.

# %%
raw_data.shape
# Out:
# (85000, 19)

# %% [markdown]
# We can see that there are 85k records and 19 features in the raw data frame

# %%
raw_data.dtypes
# Out:
# track_id             object
# track_name           object
# artist_name          object
# album_name           object
# release_date         object
# genre                object
# duration_ms           int64
# popularity            int64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# instrumentalness    float64
# tempo               float64
# stream_count          int64
# country              object
# explicit              int64
# label                object
# dtype: object

# %%
# Print the first 5 rows of the data to see what the DataFrame and records look like
raw_data.head()
# Out:
#            track_id              track_name    artist_name         album_name  \
# 0  TRK-BEBD53DA84E1         Agent every (0)    Noah Rhodes  Beautiful instead
# 1  TRK-6A32496762D7           Night respond  Jennifer Cole              Table
# 2  TRK-47AA7523463E  Future choice whatever  Brandon Davis      Page southern
# 3  TRK-25ADA22E3B06     Bad fall pick those    Corey Jones             Spring
# 4  TRK-9245F2AD996A                 Husband      Mark Diaz        Great prove
#
#   release_date  genre  duration_ms  popularity  danceability  energy  key  \
# 0   2016-04-01    Pop       234194          55          0.15    0.74    9
# 1   2022-04-15  Metal       375706          45          0.44    0.46    0
# 2   2016-02-23   Rock       289191          55          0.62    0.80    8
# 3   2015-10-12    Pop       209484          51          0.78    0.98    1
# 4   2022-07-08  Indie       127435          39          0.74    0.18   10
#
#    loudness  mode  instrumentalness   tempo  stream_count        country  \
# 0    -32.22     0             0.436   73.12         13000         Brazil
# 1    -14.02     0             0.223  157.74          1000         France
# 2    -48.26     1             0.584   71.03          1000        Germany
# 3    -34.47     1             0.684  149.00          1000         France
# 4    -17.84     0             0.304  155.85          2000  United States
#
#    explicit            label
# 0         0  Universal Music
# 1         1   Island Records
# 2         1    XL Recordings
# 3         0     Warner Music
# 4         0      Independent

# %% [markdown]
# Column insights from the head of the DataFrame
#
# - <strong>Track ID</strong> records show unique id numbers that would not be easily identified without a key. There is not a visable system to determining the track id at first glance.
# - <strong>Track Name, Artist Name,</strong> and <strong>Album Name</strong> are strings with the relavent data
# - <strong>Release date</strong> contains the year, month, and day of the release in one column. It should be converted to a datetime object.
# - <strong>Duration</strong> is measured in milliseconds. This will likely prove useful for computer analysis, but it may be helpful to add a column that shows the duration in minutes:seconds:milliseconds.
# - <strong>Popularity</strong> is measured by a two digit number for each example in the head. This column is our primary target feature for the model and will need to be inspected further.
# - <strong>Danceability</strong> and <strong>Energy</strong> are measured as a float between 0 and 1
# - <strong>Energy</strong> is float values between 0-1 showing the energy of the song
# - <strong>Key</strong> is a numeric value incidating the key of the song
# - <strong>Loudness</strong> is consistently a negative float representing the loudness of the track in decibels.
# - <strong>Mode</strong> is a boolean column representing if the songs key is major or minor (0 = minor 1 = major)
# - <strong>Instrumentalness</strong> is a float value between 0-1
# - <strong>Tempo</strong> is Beats Per Minute
# - <strong>Stream count</strong> is the number of streams for the track. We can assume that number of streams has a direct correlation with popularity of a song, and becuase our target model is to predict popularity prior to or at the early relase stages, this column will likely be dropped or become a target feature for the model to predict.
# - <strong>Country</strong> represents what Country the song performed well. In Data Exploration it will need to be explored further to determine if songs that performed well in multiple countries have multiple recoreds, or if this column actually shows the top performing country for the song.
# - <strong>Explicit</strong> - boolean showing if the song is marked as explicit
# - <strong>Label</strong> is the label that released the song

# %% [markdown]
# ### Edits and Additions to Spotify Data

# %%
# Ensure the release date is a datetime object
raw_data['release_date'] = pd.to_datetime(raw_data['release_date'])

# %%
raw_data.dtypes
# Out:
# track_id                    object
# track_name                  object
# artist_name                 object
# album_name                  object
# release_date        datetime64[ns]
# genre                       object
# duration_ms                  int64
# popularity                   int64
# danceability               float64
# energy                     float64
# key                          int64
# loudness                   float64
# mode                         int64
# instrumentalness           float64
# tempo                      float64
# stream_count                 int64
# country                     object
# explicit                     int64
# label                       object
# dtype: object

# %%
# Add a second duration column for EDA.
raw_data['duration_mm:ss:ms'] = pd.to_timedelta(raw_data['duration_ms'], unit='ms').dt.components.apply(
    lambda x: f"{x.minutes:02d}:{x.seconds:02d}:{x.milliseconds:02d}", axis=1)

# %%
raw_data.head()
# Out:
#            track_id              track_name    artist_name         album_name  \
# 0  TRK-BEBD53DA84E1         Agent every (0)    Noah Rhodes  Beautiful instead
# 1  TRK-6A32496762D7           Night respond  Jennifer Cole              Table
# 2  TRK-47AA7523463E  Future choice whatever  Brandon Davis      Page southern
# 3  TRK-25ADA22E3B06     Bad fall pick those    Corey Jones             Spring
# 4  TRK-9245F2AD996A                 Husband      Mark Diaz        Great prove
#
#   release_date  genre  duration_ms  popularity  danceability  energy  key  \
# 0   2016-04-01    Pop       234194          55          0.15    0.74    9
# 1   2022-04-15  Metal       375706          45          0.44    0.46    0
# 2   2016-02-23   Rock       289191          55          0.62    0.80    8
# 3   2015-10-12    Pop       209484          51          0.78    0.98    1
# 4   2022-07-08  Indie       127435          39          0.74    0.18   10
#
#    loudness  mode  instrumentalness   tempo  stream_count        country  \
# 0    -32.22     0             0.436   73.12         13000         Brazil
# 1    -14.02     0             0.223  157.74          1000         France
# 2    -48.26     1             0.584   71.03          1000        Germany
# 3    -34.47     1             0.684  149.00          1000         France
# 4    -17.84     0             0.304  155.85          2000  United States
#
#    explicit            label duration_mm:ss:ms
# 0         0  Universal Music         03:54:194
# 1         1   Island Records         06:15:706
# 2         1    XL Recordings         04:49:191
# 3         0     Warner Music         03:29:484
# 4         0      Independent         02:07:435

# %% [markdown]
# Next we will see how many unique values each column contains

# %%
# How many unique values does each column have?

for col in raw_data.columns:
    print(f"{col}: {raw_data[col].nunique()}")
# Out:
# track_id: 85000
# track_name: 68951
# artist_name: 62391
# album_name: 43170
# release_date: 4018
# genre: 12
# duration_ms: 75084
# popularity: 99
# danceability: 95
# energy: 98
# key: 12
# loudness: 5401
# mode: 2
# instrumentalness: 801
# tempo: 13967
# stream_count: 2250
# country: 10
# explicit: 2
# label: 8
# duration_mm:ss:ms: 75084

# %% [markdown]
# Notice while there are 85,000 unique track id's there are only 68,951 unique track names. This could mean that there are songs that share the same name, or it could mean that some songs have duplicate records. Most likely it is a combination of both. This means we will need to be careful and thorough when inspecting and dropping duplicates.

# %% [markdown]
# ### Missing and Null Values - Spotify Data
#
# In this next section we will handle missing and null values.

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85000 entries, 0 to 84999
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_id           85000 non-null  object
#  1   track_name         84979 non-null  object
#  2   artist_name        85000 non-null  object
#  3   album_name         84954 non-null  object
#  4   release_date       85000 non-null  datetime64[ns]
#  5   genre              85000 non-null  object
#  6   duration_ms        85000 non-null  int64
#  7   popularity         85000 non-null  int64
#  8   danceability       85000 non-null  float64
#  9   energy             85000 non-null  float64
#  10  key                85000 non-null  int64
#  11  loudness           85000 non-null  float64
#  12  mode               85000 non-null  int64
#  13  instrumentalness   85000 non-null  float64
#  14  tempo              85000 non-null  float64
#  15  stream_count       85000 non-null  int64
#  16  country            85000 non-null  object
#  17  explicit           85000 non-null  int64
#  18  label              85000 non-null  object
#  19  duration_mm:ss:ms  85000 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(6), object(8)
# memory usage: 13.0+ MB

# %% [markdown]
# Inspecting the info for the raw dataframe, we can see that there are some columns that do not have 85000 non-null values.

# %%
raw_data.isnull().sum()
# Out:
# track_id              0
# track_name           21
# artist_name           0
# album_name           46
# release_date          0
# genre                 0
# duration_ms           0
# popularity            0
# danceability          0
# energy                0
# key                   0
# loudness              0
# mode                  0
# instrumentalness      0
# tempo                 0
# stream_count          0
# country               0
# explicit              0
# label                 0
# duration_mm:ss:ms     0
# dtype: int64

# %% [markdown]
# Track name contains 21 missing values.

# %%
raw_data[raw_data['track_name'].isna()].sort_values(by='artist_name')
# Out:
#                track_id track_name           artist_name        album_name  \
# 71667  TRK-25F6BEF5437F        NaN           Aaron Nixon             Sense
# 47946  TRK-04F201CCB2A2        NaN        Abigail Thomas    Quality police
# 13675  TRK-530AF3473134        NaN       Brenda Calderon     Offer despite
# 83574  TRK-A7D9098C8152        NaN            Daniel Cox  Director perhaps
# 49470  TRK-A14E1F1D05D9        NaN           Eric Flores      Option there
# 67131  TRK-EBA6A845A873        NaN         Erin Petersen              Page
# 80537  TRK-EA13F1E7FB64        NaN           Frank Wolfe           Reflect
# 71882  TRK-FEABDC31C767        NaN           Gary Tanner        Throughout
# 21451  TRK-224386735616        NaN       Jesse Carpenter             Right
# 61767  TRK-6D055555336C        NaN        Jonathan Sloan       Get involve
# 3450   TRK-5F85D57B35D2        NaN        Joshua Mendoza         Sit dream
# 24387  TRK-C14EC069CE8C        NaN          Kathryn Reed    Character onto
# 53810  TRK-6C4B8B91670D        NaN        Kendra Alvarez          Whatever
# 48253  TRK-637A9B7C6388        NaN         Michael Yates        Hard which
# 35653  TRK-1D7E811646D5        NaN    Nicholas Dominguez       Significant
# 39043  TRK-3179046CDBBB        NaN        Patrick Rivers              Call
# 68906  TRK-8AD436668AB4        NaN          Ronald Perez              Size
# 29737  TRK-41E56A9B7D0F        NaN             Sara King          Material
# 38952  TRK-AE28B6340EF5        NaN           Sean Martin          Movement
# 34234  TRK-E813D431BEFF        NaN  Stephanie Villarreal           Receive
# 70512  TRK-C14786CC0D16        NaN         Taylor Willis    Join including
#
#       release_date      genre  duration_ms  popularity  danceability  energy  \
# 71667   2018-03-11       Jazz       142662          54          0.24    0.99
# 47946   2024-09-02    Country       281128          65          0.50    0.74
# 13675   2019-02-27      Indie       159043          35          0.51    0.58
# 83574   2024-09-08      Indie       153590          59          0.73    0.60
# 49470   2023-07-06       Jazz       360475          31          0.67    0.47
# 67131   2017-01-18       Folk       322652          31          0.83    0.23
# 80537   2021-12-02        EDM       196142          52          0.85    0.89
# 71882   2019-10-08    Hip-Hop       398762          65          0.65    0.20
# 21451   2021-06-11    Country       269462          50          0.32    0.72
# 61767   2018-03-06      Metal       403909          53          0.44    0.42
# 3450    2024-08-20        EDM       317305          42          0.74    0.47
# 24387   2017-03-15  Reggaeton       145197          44          0.09    0.51
# 53810   2016-05-22    Country       120143          39          0.76    0.27
# 48253   2025-04-03    Country       378527          48          0.94    0.84
# 35653   2019-07-14      Indie       135849          39          0.68    0.31
# 39043   2015-09-14        Pop       239337          30          0.41    0.24
# 68906   2015-07-21       Rock       385793          68          0.61    0.22
# 29737   2015-01-15      Indie       385848          71          0.40    0.53
# 38952   2019-04-13  Classical       115179          35          0.15    0.99
# 34234   2019-09-20        R&B       271598          23          0.22    0.81
# 70512   2020-12-21       Rock       154105          58          0.78    0.31
#
#        key  loudness  mode  instrumentalness   tempo  stream_count  \
# 71667   10    -22.01     0             0.784  106.37         18000
# 47946    2    -17.92     1             0.352   89.28         79000
# 13675    9    -48.51     0             0.415   67.81          1000
# 83574    2    -40.17     1             0.498   86.30          1000
# 49470   10    -34.79     1             0.420  102.42          1000
# 67131   10    -28.57     0             0.447   88.73          1000
# 80537    8    -37.18     1             0.053   83.38          1000
# 71882    3    -40.41     1             0.643   64.43          3000
# 21451    8    -26.73     0             0.604  115.88          1000
# 61767    7    -13.95     1             0.450  146.22          3000
# 3450     6    -33.19     0             0.405  123.45          1000
# 24387    3    -33.23     0             0.777   83.98          1000
# 53810    1    -16.57     1             0.388   90.47          1000
# 48253    2    -49.54     0             0.435  155.57          4000
# 35653   11    -27.62     1             0.640   82.50         50000
# 39043    1    -14.09     1             0.231  176.79          1000
# 68906    0    -30.44     1             0.658  142.38         12000
# 29737    7    -23.11     1             0.078  106.65         99000
# 38952    7    -52.87     0             0.182  163.13          1000
# 34234    6    -36.35     0             0.716   77.10          1000
# 70512    2    -13.52     0             0.290   65.20          3000
#
#               country  explicit            label duration_mm:ss:ms
# 71667         Germany         0      Independent         02:22:662
# 47946          Brazil         0    XL Recordings         04:41:128
# 13675           India         1       Sony Music          02:39:43
# 83574         Germany         0      Independent         02:33:590
# 49470          Mexico         0       Sony Music         06:00:475
# 67131          Canada         0       Sony Music         05:22:652
# 80537  United Kingdom         1     Warner Music         03:16:142
# 71882  United Kingdom         0         Columbia         06:38:762
# 21451  United Kingdom         0     Warner Music         04:29:462
# 61767           Japan         0    XL Recordings         06:43:909
# 3450    United States         0     Warner Music         05:17:305
# 24387          Canada         0      Independent         02:25:197
# 53810  United Kingdom         0  Universal Music         02:00:143
# 48253           Japan         0   Island Records         06:18:527
# 35653           India         0   Island Records         02:15:849
# 39043       Australia         0              EMI         03:59:337
# 68906           Japan         0    XL Recordings         06:25:793
# 29737          France         0       Sony Music         06:25:848
# 38952         Germany         0   Island Records         01:55:179
# 34234   United States         0      Independent         04:31:598
# 70512          France         0   Island Records         02:34:105

# %% [markdown]
# With 21 tracks that do not have values for track name, it is best to fill these values with the string "Unknown" to keep their data to train and test the model. It is possible that the clients utalize the final version of the model will have working titles or no track name for the new songs, and therefore may use the 'Unknown' or null value when using the model.
#
# Before filling the missing values, are there any existing songs with the string 'Unknown' already?

# %%
unknown_tracks = raw_data[raw_data['track_name'].str.lower() == 'unknown']

print(f"There are {len(unknown_tracks)} tracks with the name Unknown")
# Out:
# There are 0 tracks with the name Unknown

# %% [markdown]
# With 0 existing track names as "Unknown", missing track names will be filled with the string "Unknwon"

# %%
raw_data['track_name'] = raw_data['track_name'].fillna('Unknown')

# %%
unknown_tracks_new = raw_data[raw_data['track_name'].str.lower() == 'unknown']

print(f"There are {len(unknown_tracks_new)} tracks with the name Unknown")
# Out:
# There are 21 tracks with the name Unknown

# %% [markdown]
# Album name contains 46 missing values

# %%
raw_data[raw_data['album_name'].isna()].sort_values(by='artist_name')
# Out:
#                track_id                             track_name  \
# 21674  TRK-65DC223A2CFC                           Popular west
# 59848  TRK-48D99EDCE521                   Fish will population
# 65401  TRK-3C0B06599311                        Suffer when and
# 13690  TRK-827D10EBAB35                                   News
# 31598  TRK-073E69DAAF9D                               Its part
# 59011  TRK-39F249470C99                         Throw Democrat
# 29079  TRK-54D6D4C1826C                            Leader yeah
# 37737  TRK-5AF9D6599F95                        Study bill mind
# 64361  TRK-8BF8D0EC5A26        Should around official official
# 47664  TRK-99BEEE17B44B                        Determine model
# 81603  TRK-ED9C1665E45B                               Way same
# 53921  TRK-8506AE47594B                         Sometimes list
# 16130  TRK-C27D01E09D45                                  Plant
# 5501   TRK-2C00D79ABB40                      Not but upon tend
# 76902  TRK-5D0E2CDCE168               Close he sort term fight
# 63546  TRK-1228D166D807                     Lead least picture
# 78856  TRK-27D344A89473                                 Return
# 78217  TRK-E78575FC6B6C                           Activity ten
# 12192  TRK-7FB3DD5B8CD8               Feel network institution
# 23506  TRK-65649478788D                        State full hope
# 19994  TRK-A8E25520A0E1                  Career rest out while
# 43898  TRK-2ECD944D5B4C                        Similar soldier
# 20447  TRK-9422B0D27B50                        While fine even
# 40316  TRK-195C1794DF06                            Sit involve
# 22323  TRK-E0B0CBB0CCC7              Then fast newspaper stage
# 36151  TRK-EAB43CC2A434                 Important usually hour
# 73820  TRK-82DD6EDE9B85                        Mrs range model
# 33043  TRK-2D907AD73D91                             Land admit
# 1524   TRK-160AEB256B3C                    Wait never fly pull
# 20868  TRK-96C618FC18E3                                 Expert
# 75801  TRK-91EEDB491E7C                                   Here
# 17942  TRK-106F70496DA3                               American
# 73268  TRK-20B3A0529663                       Receive maintain
# 18492  TRK-7CAE6E9D1C60             Project say leader involve
# 20833  TRK-FEA7FBB049FF                        Something focus
# 27019  TRK-326BE7F6F909                                   Grow
# 65908  TRK-D8070AABB527                       Decision medical
# 12661  TRK-EF94B1759037  Imagine tree successful relate anyone
# 63747  TRK-DC5BFC1842D1                          Soldier state
# 55419  TRK-180082A14CBE                      Quality certainly
# 9222   TRK-1AD30763AA15                          Create be bit
# 75658  TRK-14892DF7A26F                         Allow everyone
# 75098  TRK-D80FEB8CF3CA                Investment claim career
# 48497  TRK-F95689B9DA8D       Tell meeting capital face design
# 61665  TRK-EC2BBD3924C4                                    She
# 29559  TRK-05A86FD3869D                                Reality
#
#                 artist_name album_name release_date      genre  duration_ms  \
# 21674          Abigail Hall        NaN   2023-01-04        R&B       389171
# 59848        Amanda Harding        NaN   2024-01-19  Classical       307684
# 65401          Amanda Smith        NaN   2024-10-05        R&B       194777
# 13690       Anna Villarreal        NaN   2023-08-08       Rock       149590
# 31598            Anne Burns        NaN   2015-06-13        Pop       133232
# 59011      Anthony Anderson        NaN   2017-04-04       Rock       328667
# 29079       Anthony Daniels        NaN   2021-07-24       Jazz       156435
# 37737        Ashley Krueger        NaN   2021-08-20  Classical       232750
# 64361         Brandon White        NaN   2023-04-11      Metal       139769
# 47664           Brent Ortiz        NaN   2016-02-03        EDM       225143
# 81603            Brett King        NaN   2024-12-27        EDM       254703
# 53921      Catherine Taylor        NaN   2024-11-12      Metal       283932
# 16130            Cory Smith        NaN   2015-10-11      Indie       396575
# 5501          Curtis Morris        NaN   2021-07-23      Indie       254159
# 76902         Cynthia Lewis        NaN   2016-05-04        EDM       249417
# 63546        Cynthia Norton        NaN   2025-08-20       Folk       340005
# 78856         David Johnson        NaN   2017-10-13        Pop       391695
# 78217  Dr. Michael Price II        NaN   2016-02-27        Pop       283640
# 12192      Elizabeth Gordon        NaN   2017-11-08        EDM       376103
# 23506           Erica Haney        NaN   2019-11-30        EDM       329769
# 19994           Gary Torres        NaN   2022-05-07       Rock       379020
# 43898          George James        NaN   2023-05-27      Indie       316995
# 20447    Heather Villarreal        NaN   2022-12-31        EDM       254816
# 40316             Ian Evans        NaN   2025-08-12        Pop       413834
# 22323        James Cardenas        NaN   2016-08-03    Hip-Hop       268905
# 36151       Jessica Calhoun        NaN   2015-06-22    Country       205560
# 73820          Jessica Reed        NaN   2019-08-02        Pop       131681
# 33043      Jillian Williams        NaN   2020-02-04      Indie       187156
# 1524            Jose Palmer        NaN   2025-06-16        R&B       313674
# 20868        Kathryn Gentry        NaN   2015-04-28        R&B       352829
# 75801      Kenneth Cantrell        NaN   2015-11-13  Classical       263789
# 17942            Kim Palmer        NaN   2022-09-20        EDM       163145
# 73268       Krista Odonnell        NaN   2018-12-19        Pop       210730
# 18492         Mark Mitchell        NaN   2023-07-24       Folk       261802
# 20833          Mark Perkins        NaN   2020-11-22    Hip-Hop       236229
# 27019        Matthew Newton        NaN   2025-10-13    Hip-Hop       221743
# 65908      Mr. Robert Baker        NaN   2019-04-14    Hip-Hop       114127
# 12661        Rachael Mendez        NaN   2017-04-01      Indie       390016
# 63747           Robert Tran        NaN   2025-03-23        EDM       369603
# 55419          Sheila Nunez        NaN   2015-08-14        Pop        96378
# 9222    Stephanie Rodriguez        NaN   2017-03-24  Classical       191961
# 75658          Terry Kaiser        NaN   2019-04-08    Country        92093
# 75098           Thomas Wood        NaN   2016-04-25    Country       144713
# 48497         Tracy Holland        NaN   2018-08-31        EDM       367620
# 61665        William Hudson        NaN   2023-03-17        Pop       235035
# 29559         William Smith        NaN   2024-07-26      Indie       258132
#
#        popularity  danceability  energy  key  loudness  mode  \
# 21674          48          0.34    0.94    0    -50.14     0
# 59848          40          0.33    0.28    9    -34.30     0
# 65401          78          0.23    0.66    0    -51.36     0
# 13690          35          0.09    0.61    6    -47.29     1
# 31598          47          0.53    0.42    7    -47.02     1
# 59011          49          0.59    0.93    5    -45.25     0
# 29079          70          0.53    0.62    8     -6.54     1
# 37737          67          0.24    0.11   10    -25.58     1
# 64361          64          0.92    0.67    8    -32.42     0
# 47664          54          0.52    0.92   10    -25.22     1
# 81603          46          0.88    0.70    4    -35.92     1
# 53921          42          0.31    0.53    9    -44.92     0
# 16130          46          0.82    0.72    4    -30.91     0
# 5501           38          0.82    0.94   11    -43.60     1
# 76902          47          0.10    0.99    6    -14.96     1
# 63546          80          0.38    0.15    6    -11.59     0
# 78856          32          0.85    0.33    4    -34.48     1
# 78217          39          0.22    0.24    7     -4.50     0
# 12192          48          0.58    0.41    4    -26.50     1
# 23506          54          0.93    0.49    6    -28.10     0
# 19994          61          0.44    0.51    2     -9.73     0
# 43898          48          0.19    0.53    7    -39.62     0
# 20447          48          0.83    0.38    8    -15.27     1
# 40316          35          0.44    0.85    6    -54.20     0
# 22323          36          0.94    0.09   11    -29.74     0
# 36151          51          0.88    0.17    8    -52.70     1
# 73820          27          0.91    0.60    9    -22.72     1
# 33043          49          0.44    0.07    1    -40.98     0
# 1524           18          0.15    0.93    9    -33.36     0
# 20868          45          0.85    0.55   11    -27.85     0
# 75801          54          0.68    0.10    3    -17.89     1
# 17942          47          0.37    0.63    9    -48.89     0
# 73268          48          0.35    0.33    1    -45.63     0
# 18492          61          0.16    0.15   11    -29.39     0
# 20833          35          0.24    0.16   10    -24.59     1
# 27019          56          0.40    0.72    7    -44.49     0
# 65908          46          0.65    0.35    8    -16.66     1
# 12661          46          0.58    0.45    9    -20.04     1
# 63747          38          0.19    0.19    0    -27.84     0
# 55419          34          0.31    0.50   11    -30.55     0
# 9222           27          0.35    0.54    0    -41.18     1
# 75658          68          0.13    0.29   11    -54.19     1
# 75098          25          0.80    0.24    6    -37.33     0
# 48497          28          0.67    0.78    6     -8.62     0
# 61665          65          0.95    0.68    4    -29.87     0
# 29559          49          0.49    0.17    1     -7.19     0
#
#        instrumentalness   tempo  stream_count         country  explicit  \
# 21674             0.314   93.10          7000          France         0
# 59848             0.658  176.70          1000         Germany         0
# 65401             0.647  120.59       1298000   United States         1
# 13690             0.128  128.09          1000          France         0
# 31598             0.677  133.69          1000  United Kingdom         1
# 59011             0.228  170.44          1000  United Kingdom         1
# 29079             0.450   69.56         19000  United Kingdom         0
# 37737             0.744   73.22          1000          Mexico         0
# 64361             0.541   71.52          8000   United States         0
# 47664             0.486   90.04          1000          Canada         1
# 81603             0.525   63.29          2000          Mexico         0
# 53921             0.285  178.86         20000          Canada         1
# 16130             0.306  106.25          3000         Germany         0
# 5501              0.034  111.11          1000         Germany         0
# 76902             0.679  191.25          4000          Canada         0
# 63546             0.329  194.21        120000           India         0
# 78856             0.030  199.27          1000          France         0
# 78217             0.080   99.74          1000          Brazil         1
# 12192             0.111  116.27         14000          Brazil         1
# 23506             0.370  144.18         92000           Japan         0
# 19994             0.783   60.82          3000       Australia         0
# 43898             0.602   95.24         27000          Canada         0
# 20447             0.475  126.40         20000  United Kingdom         0
# 40316             0.632   66.29          1000           India         0
# 22323             0.110   74.74          1000          France         1
# 36151             0.228  145.35          4000       Australia         1
# 73820             0.345   93.99          1000         Germany         0
# 33043             0.033   78.72          1000           India         0
# 1524              0.447  150.86          1000          France         0
# 20868             0.571  101.18          1000       Australia         0
# 75801             0.425  118.78          3000  United Kingdom         0
# 17942             0.474  102.85          1000   United States         0
# 73268             0.186  107.57          3000  United Kingdom         0
# 18492             0.072  102.43         20000       Australia         0
# 20833             0.041  108.93          3000          Canada         0
# 27019             0.758  178.41          4000       Australia         0
# 65908             0.493  178.71          1000          Mexico         0
# 12661             0.164  126.09          2000           India         0
# 63747             0.171   98.08          7000          Mexico         1
# 55419             0.550  181.74          3000   United States         0
# 9222              0.419   91.50          1000       Australia         0
# 75658             0.771  141.19         25000       Australia         0
# 75098             0.114  135.94          1000           India         1
# 48497             0.245  155.90          2000          Brazil         0
# 61665             0.686  150.50          8000  United Kingdom         0
# 29559             0.097   64.70          1000          Brazil         0
#
#                  label duration_mm:ss:ms
# 21674         Columbia         06:29:171
# 59848         Columbia         05:07:684
# 65401       Sony Music         03:14:777
# 13690  Universal Music         02:29:590
# 31598      Independent         02:13:232
# 59011   Island Records         05:28:667
# 29079  Universal Music         02:36:435
# 37737         Columbia         03:52:750
# 64361   Island Records         02:19:769
# 47664     Warner Music         03:45:143
# 81603       Sony Music         04:14:703
# 53921   Island Records         04:43:932
# 16130  Universal Music         06:36:575
# 5501   Universal Music         04:14:159
# 76902              EMI         04:09:417
# 63546       Sony Music          05:40:05
# 78856   Island Records         06:31:695
# 78217      Independent         04:43:640
# 12192    XL Recordings         06:16:103
# 23506       Sony Music         05:29:769
# 19994      Independent          06:19:20
# 43898      Independent         05:16:995
# 20447     Warner Music         04:14:816
# 40316   Island Records         06:53:834
# 22323   Island Records         04:28:905
# 36151   Island Records         03:25:560
# 73820  Universal Music         02:11:681
# 33043     Warner Music         03:07:156
# 1524               EMI         05:13:674
# 20868       Sony Music         05:52:829
# 75801         Columbia         04:23:789
# 17942    XL Recordings         02:43:145
# 73268  Universal Music         03:30:730
# 18492         Columbia         04:21:802
# 20833    XL Recordings         03:56:229
# 27019       Sony Music         03:41:743
# 65908       Sony Music         01:54:127
# 12661  Universal Music          06:30:16
# 63747  Universal Music         06:09:603
# 55419       Sony Music         01:36:378
# 9222        Sony Music         03:11:961
# 75658       Sony Music          01:32:93
# 75098  Universal Music         02:24:713
# 48497       Sony Music         06:07:620
# 61665     Warner Music          03:55:35
# 29559   Island Records         04:18:132

# %% [markdown]
# The album name may be missing for several reasons - possibly the song was released as a single, possibly the song is not associated with a specific album. With the developments in digital released music vs CD's, many artists are releaseing songs as they're complete rather than as a full album. Ideally our model will assist the clients with making determinations for the best strategy to relase songs, so we do not want to drop the album_name column completly at this stage.
#
# However, the album name should not be simply filled with "Unknown" as we did for track_name becasue unlike track_name, there is no unique identifier for Album Name. If we filled with 'Unknown' or something similar, all 46 records with the same album name, the model may think these are all associated and create a fake relationship between them. To protect the integrity of our data these records with missing values for album_name will be dropped.

# %%
raw_data = raw_data.dropna(subset=['album_name'])

# %%
raw_data.shape
# Out:
# (84954, 20)

# %%
raw_data.isnull().sum()
# Out:
# track_id             0
# track_name           0
# artist_name          0
# album_name           0
# release_date         0
# genre                0
# duration_ms          0
# popularity           0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# instrumentalness     0
# tempo                0
# stream_count         0
# country              0
# explicit             0
# label                0
# duration_mm:ss:ms    0
# dtype: int64

# %% [markdown]
# All missing values have been appropriately filled or dropped.

# %% [markdown]
# ### Duplicate Values - Spotify Data

# %%
exact_duplicates = raw_data.duplicated().sum()
print(f"Therea are {exact_duplicates} identical records")
# Out:
# Therea are 0 identical records

# %%
trackid_duplicates = raw_data['track_id'].duplicated().sum()
print(f"Duplicated Track IDs: {trackid_duplicates}")
# Out:
# Duplicated Track IDs: 0

# %% [markdown]
# With 0 identical records, and 0 duplicated track_id in the dataset it appears there are no duplicate values. But what if a track was released on a single, then later re-released on an album and was assigned two different unique track id's?

# %%
song_duplicates = raw_data[raw_data.duplicated(subset=['track_name', 'artist_name'], keep=False)]
print(f"Same Song/Artist pairs: {len(song_duplicates)}")
# Out:
# Same Song/Artist pairs: 6

# %%
song_duplicates.sort_values(by=['track_name', 'artist_name'])
# Out:
#                track_id track_name      artist_name         album_name  \
# 23411  TRK-A82E8EFECB98       Much  Michael Johnson               Then
# 26515  TRK-92BA06C1E3B6       Much  Michael Johnson  Structure feeling
# 7993   TRK-2C9D28974FB8     Nation      Brian Brown       Ten indicate
# 70052  TRK-186996D361F3     Nation      Brian Brown         West whole
# 27950  TRK-137F1682414B       Very  Jennifer Torres               Data
# 61960  TRK-042055F5DE76       Very  Jennifer Torres    Expert magazine
#
#       release_date      genre  duration_ms  popularity  danceability  energy  \
# 23411   2017-04-09    Country       418279          38          0.06    0.09
# 26515   2025-10-22  Classical       113486          27          0.75    0.07
# 7993    2018-07-04        Pop       344352          42          0.22    0.91
# 70052   2019-05-17    Country       242090          65          0.34    0.43
# 27950   2016-06-06        Pop       118473          40          0.89    0.11
# 61960   2016-04-24        R&B       381545          41          0.50    0.30
#
#        key  loudness  mode  instrumentalness   tempo  stream_count  \
# 23411    0    -16.92     1             0.352   85.78          3000
# 26515    5     -4.85     0             0.436   79.05          1000
# 7993     0    -13.68     1             0.059  177.17          3000
# 70052    5    -10.06     0             0.431  155.68          5000
# 27950    9     -6.17     1             0.111  109.99          6000
# 61960    8    -38.20     0             0.448  181.85          6000
#
#              country  explicit           label duration_mm:ss:ms
# 23411      Australia         0        Columbia         06:58:279
# 26515         Brazil         0      Sony Music         01:53:486
# 7993          Canada         1        Columbia         05:44:352
# 70052          Japan         1        Columbia          04:02:90
# 27950  United States         1     Independent         01:58:473
# 61960         Canada         0  Island Records         06:21:545

# %% [markdown]
# We found that there are 3 songs that were re-released by their original artists, however inspecting the other attributes it is clear that these are re-releases of the original song in a different genre, energy, or other different aspect. We will keep these songs for not, but will flag them for consideration after exploratory data analysis. These records can be insightful to popularity based on how popular the re-relases are based on the chaged attributes

# %% [markdown]
# <strong>Based on these findings there are no identical duplicates to be dropped</strong>

# %% [markdown]
# With the spotify data fully wrangled, I will copy the DataFrame into a new DataFrame calleed "spotify_data" to make it clear when merging in the next steps

# %%
spotify_data = raw_data.copy()

# %% [markdown]
# ## Country Data

# %% [markdown]
# ### Importing Country Data
#
# To add features and data for our model to train and test on, I will be adding country data to our data frame. The steps below are taken to import that country data.

# %%
unique_countries = spotify_data['country'].unique().tolist()

# %%
unique_countries
# Out:
# ['Brazil',
#  'France',
#  'Germany',
#  'United States',
#  'Australia',
#  'United Kingdom',
#  'Japan',
#  'Canada',
#  'India',
#  'Mexico']

# %% [markdown]
# United States and United Kingdom do not exactly match the names of the countries for the api call and must be changed

# %%
mapping = {
    'United States': 'United States of America',
    'United Kingdom': 'United Kingdom of Great Britain and Northern Ireland'
}

unique_countries = [mapping.get(country, country) for country in unique_countries]

# %%
unique_countries
# Out:
# ['Brazil',
#  'France',
#  'Germany',
#  'United States of America',
#  'Australia',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'Japan',
#  'Canada',
#  'India',
#  'Mexico']

# %%
BASE_URL = "https://www.apicountries.com/name"

country_data = []

for country in unique_countries:
    encoded_country = quote(country)
    url = f"{BASE_URL}/{encoded_country}"

    retries = 3

    for attempt in range(retries):
        response = requests.get(url)

        if response.status_code == 200:
            data = response.json()

            if isinstance(data, list) and len(data) > 0:
                country_data.append(data[0])
            break

        elif response.status_code == 429:
            wait_time = 2 ** attempt
            time.sleep(wait_time)

        else:
            print(f"Failed to fetch {country}: {response.status_code}")
            break

    time.sleep(1.2)

countries_df = pd.json_normalize(country_data)

countries_df.head()
# Out:
#                        name topLevelDomain alpha2Code alpha3Code callingCodes  \
# 0                    Brazil          [.br]         BR        BRA         [55]
# 1                    France          [.fr]         FR        FRA         [33]
# 2                   Germany          [.de]         DE        DEU         [49]
# 3  United States of America          [.us]         US        USA          [1]
# 4                 Australia          [.au]         AU        AUS         [61]
#
#             capital                                       altSpellings  \
# 0          Brasília  [BR, Brasil, Federative Republic of Brazil, Re...
# 1             Paris        [FR, French Republic, République française]
# 2            Berlin  [DE, Federal Republic of Germany, Bundesrepubl...
# 3  Washington, D.C.                [US, USA, United States of America]
# 4          Canberra                                               [AU]
#
#                    subregion    region  population  ... translations.pt  \
# 0              South America  Americas   212559409  ...          Brasil
# 1             Western Europe    Europe    67391582  ...          França
# 2             Central Europe    Europe    83240525  ...        Alemanha
# 3           Northern America  Americas   329484123  ...  Estados Unidos
# 4  Australia and New Zealand   Oceania    25687041  ...       Austrália
#
#     translations.nl             translations.hr      translations.fa  \
# 0          Brazilië                      Brazil                برزیل
# 1         Frankrijk                   Francuska               فرانسه
# 2         Duitsland                    Njemačka                آلمان
# 3  Verenigde Staten  Sjedinjene Američke Države  ایالات متحده آمریکا
# 4         Australië                  Australija             استرالیا
#
#                   translations.de translations.es translations.fr  \
# 0                       Brasilien          Brasil          Brésil
# 1                      Frankreich         Francia          France
# 2                     Deutschland        Alemania       Allemagne
# 3  Vereinigte Staaten von Amerika  Estados Unidos      États-Unis
# 4                      Australien       Australia       Australie
#
#   translations.ja        translations.it            translations.hu
# 0            ブラジル                Brasile                   Brazília
# 1            フランス                Francia              Franciaország
# 2             ドイツ               Germania                     Grúzia
# 3         アメリカ合衆国  Stati Uniti D'America  Amerikai Egyesült Államok
# 4         オーストラリア              Australia                 Ausztrália
#
# [5 rows x 37 columns]

# %%
countries_df
# Out:
#                                                 name topLevelDomain  \
# 0                                             Brazil          [.br]
# 1                                             France          [.fr]
# 2                                            Germany          [.de]
# 3                           United States of America          [.us]
# 4                                          Australia          [.au]
# 5  United Kingdom of Great Britain and Northern I...          [.uk]
# 6                                              Japan          [.jp]
# 7                                             Canada          [.ca]
# 8                     British Indian Ocean Territory          [.io]
# 9                                             Mexico          [.mx]
#
#   alpha2Code alpha3Code callingCodes           capital  \
# 0         BR        BRA         [55]          Brasília
# 1         FR        FRA         [33]             Paris
# 2         DE        DEU         [49]            Berlin
# 3         US        USA          [1]  Washington, D.C.
# 4         AU        AUS         [61]          Canberra
# 5         GB        GBR         [44]            London
# 6         JP        JPN         [81]             Tokyo
# 7         CA        CAN          [1]            Ottawa
# 8         IO        IOT        [246]      Diego Garcia
# 9         MX        MEX         [52]       Mexico City
#
#                                         altSpellings  \
# 0  [BR, Brasil, Federative Republic of Brazil, Re...
# 1        [FR, French Republic, République française]
# 2  [DE, Federal Republic of Germany, Bundesrepubl...
# 3                [US, USA, United States of America]
# 4                                               [AU]
# 5                            [GB, UK, Great Britain]
# 6                                [JP, Nippon, Nihon]
# 7                                               [CA]
# 8                                               [IO]
# 9  [MX, Mexicanos, United Mexican States, Estados...
#
#                    subregion    region  population  ...  \
# 0              South America  Americas   212559409  ...
# 1             Western Europe    Europe    67391582  ...
# 2             Central Europe    Europe    83240525  ...
# 3           Northern America  Americas   329484123  ...
# 4  Australia and New Zealand   Oceania    25687041  ...
# 5            Northern Europe    Europe    67215293  ...
# 6               Eastern Asia      Asia   125836021  ...
# 7           Northern America  Americas    38005238  ...
# 8             Eastern Africa    Africa        3000  ...
# 9              North America  Americas   128932753  ...
#
#                          translations.pt  \
# 0                                 Brasil
# 1                                 França
# 2                               Alemanha
# 3                         Estados Unidos
# 4                              Austrália
# 5                            Reino Unido
# 6                                  Japão
# 7                                 Canadá
# 8  Território Britânico do Oceano Índico
# 9                                 México
#
#                          translations.nl  \
# 0                               Brazilië
# 1                              Frankrijk
# 2                              Duitsland
# 3                       Verenigde Staten
# 4                              Australië
# 5                    Verenigd Koninkrijk
# 6                                  Japan
# 7                                 Canada
# 8  Britse Gebieden in de Indische Oceaan
# 9                                 Mexico
#
#                         translations.hr                translations.fa  \
# 0                                Brazil                          برزیل
# 1                             Francuska                         فرانسه
# 2                              Njemačka                          آلمان
# 3            Sjedinjene Američke Države            ایالات متحده آمریکا
# 4                            Australija                       استرالیا
# 5                Ujedinjeno Kraljevstvo  بریتانیای کبیر و ایرلند شمالی
# 6                                 Japan                           ژاپن
# 7                                Kanada                         کانادا
# 8  Britanski Indijskooceanski teritorij  قلمرو بریتانیا در اقیانوس هند
# 9                               Meksiko                          مکزیک
#
#                              translations.de  \
# 0                                  Brasilien
# 1                                 Frankreich
# 2                                Deutschland
# 3             Vereinigte Staaten von Amerika
# 4                                 Australien
# 5                     Vereinigtes Königreich
# 6                                      Japan
# 7                                     Kanada
# 8  Britisches Territorium im Indischen Ozean
# 9                                     Mexiko
#
#                           translations.es  \
# 0                                  Brasil
# 1                                 Francia
# 2                                Alemania
# 3                          Estados Unidos
# 4                               Australia
# 5                             Reino Unido
# 6                                   Japón
# 7                                  Canadá
# 8  Territorio Británico del Océano Índico
# 9                                  México
#
#                             translations.fr translations.ja  \
# 0                                    Brésil            ブラジル
# 1                                    France            フランス
# 2                                 Allemagne             ドイツ
# 3                                États-Unis         アメリカ合衆国
# 4                                 Australie         オーストラリア
# 5                               Royaume-Uni            イギリス
# 6                                     Japon              日本
# 7                                    Canada             カナダ
# 8  Territoire britannique de l'océan Indien     イギリス領インド洋地域
# 9                                   Mexique            メキシコ
#
#                              translations.it             translations.hu
# 0                                    Brasile                    Brazília
# 1                                    Francia               Franciaország
# 2                                   Germania                      Grúzia
# 3                      Stati Uniti D'America   Amerikai Egyesült Államok
# 4                                  Australia                  Ausztrália
# 5                                Regno Unito              Nagy-Britannia
# 6                                   Giappone                       Japán
# 7                                     Canada                      Kanada
# 8  Territorio britannico dell'oceano indiano  Brit Indiai-óceáni Terület
# 9                                    Messico                      Mexikó
#
# [10 rows x 37 columns]

# %%
#save the raw country data as a csv file

countries_df.to_csv('../Data/country_raw_data.csv', index=False)

# %% [markdown]
# ### Cleaning Country Data

# %% [markdown]
# Some of these columns are clearly not needed for this project. Those columns will be dropped:
# - topLevelDomain
# - callingCodes
# - altSpellings
# - flag
# - flags.svg
# - flags.png
# - all translation columns

# %%
country_mapping = {
    'United States of America': 'United States',
    'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom',
    'British Indian Ocean Territory': 'India'
}

countries_df['name'] = countries_df['name'].replace(country_mapping)

# %%
drop_cols = [
    'topLevelDomain', 
    'callingCodes',
    'altSpellings',
    'flag',
    'flags.svg',
    'flags.png'
]

countries_df.drop(columns=drop_cols, inplace=True)

# %%
countries_df = countries_df.loc[
    :, ~countries_df.columns.str.startswith("translations.")]

# %% [markdown]
# To ensure consistent formatting the region and subregion columns will be normalized into all lower case strings and numeric columns will be converted to numeric.

# %%
# Normalize columns
countries_df["region"] = countries_df["region"].str.lower()
countries_df["subregion"] = countries_df["subregion"].str.lower()

# %%
# Convert numeric columns

numeric_cols = [
    "population",
    "area",
    "gini",
    "numericCode"
]

countries_df[numeric_cols] = countries_df[numeric_cols].apply(
    pd.to_numeric, errors="coerce"
)

# %%
countries_df[numeric_cols].describe()
# Out:
#          population          area       gini  numericCode
# count  1.000000e+01  1.000000e+01   9.000000    10.000000
# mean   1.078355e+08  3.940461e+06  37.800000   339.000000
# std    9.888682e+07  4.389695e+06   7.425968   297.229055
# min    3.000000e+03  6.000000e+01  31.900000    36.000000
# 25%    4.530775e+07  3.623180e+05  32.900000    95.500000
# 50%    7.531605e+07  1.302527e+06  34.400000   263.000000
# 75%    1.281586e+08  8.309831e+06  41.400000   461.000000
# max    3.294841e+08  9.984670e+06  53.400000   840.000000

# %%
countries_df[numeric_cols].isna().sum().sort_values(ascending=False)
# Out:
# gini           1
# population     0
# area           0
# numericCode    0
# dtype: int64

# %%
countries_df[countries_df['gini'].isna()]
# Out:
#     name alpha2Code alpha3Code       capital       subregion  region  \
# 8  India         IO        IOT  Diego Garcia  eastern africa  africa
#
#    population      latlng demonym  area  ...  \
# 8        3000  [-6, 71.5]  Indian    60  ...
#
#                          translations.pt  \
# 8  Território Britânico do Oceano Índico
#
#                          translations.nl  \
# 8  Britse Gebieden in de Indische Oceaan
#
#                         translations.hr                translations.fa  \
# 8  Britanski Indijskooceanski teritorij  قلمرو بریتانیا در اقیانوس هند
#
#                              translations.de  \
# 8  Britisches Territorium im Indischen Ozean
#
#                           translations.es  \
# 8  Territorio Británico del Océano Índico
#
#                             translations.fr translations.ja  \
# 8  Territoire britannique de l'océan Indien     イギリス領インド洋地域
#
#                              translations.it             translations.hu
# 8  Territorio britannico dell'oceano indiano  Brit Indiai-óceáni Terület
#
# [1 rows x 31 columns]

# %% [markdown]
# India has a null value for gini. This data could be very important for our model. Since the API is unable to provide the information it will be filled with the value reported by the World Bank. This data shows the most recent report for India was in 2022 and the Gini was 25.5. That value will be manually input to preserve the dataset. This data was obtained from https://data.worldbank.org/indicator/SI.POV.GINI.

# %%
countries_df.loc[countries_df['name'] == 'India', 'gini'] = 25.5

# %%
countries_df['gini'].loc[countries_df['name'] == 'India']
# Out:
# 8    25.5
# Name: gini, dtype: float64

# %%
countries_df[numeric_cols].isna().sum().sort_values(ascending=False)
# Out:
# population     0
# area           0
# gini           0
# numericCode    0
# dtype: int64

# %%
countries_df.dtypes
# Out:
# name                object
# alpha2Code          object
# alpha3Code          object
# capital             object
# subregion           object
# region              object
# population           int64
# latlng              object
# demonym             object
# area                 int64
# gini               float64
# timezones           object
# borders             object
# nativeName          object
# numericCode          int64
# currencies          object
# languages           object
# regionalBlocs       object
# cioc                object
# independent           bool
# translations.br     object
# translations.pt     object
# translations.nl     object
# translations.hr     object
# translations.fa     object
# translations.de     object
# translations.es     object
# translations.fr     object
# translations.ja     object
# translations.it     object
# translations.hu     object
# dtype: object

# %% [markdown]
# ### Edits and Additions to Country Data

# %% [markdown]
# While closely inspecting the DataFrame, several columns contain values of lists or lists of dictionaries. Each of these need to be handled individually

# %% [markdown]
# <strong>Timezones</strong><br>
# The timezone column contains lists of the timezones that the country contains. Since there is a column containing 'region' information, it is not needed to know the specific time zones in a country, but it could be useful to know the total number of timezones a particular country contains.

# %%
countries_df['num_timezones'] = countries_df['timezones'].apply(
    lambda x: len(x) if isinstance(x, list) else 0
)

# %% [markdown]
# <strong>Borders</strong><br>
# The borders column contains lists of all the country codes that border the country. Similar to timezones, the data of specific countries borderd is not needed due to the region column. Once again we'll count the number of bording countries and use that data.

# %%
countries_df['num_borders'] = countries_df['borders'].apply(
    lambda x: len(x) if isinstance(x, list) else 0
)

# %% [markdown]
# <strong>Currencies</strong><br>
# The currencies column contains a list of a dictionary for each country with the official currency. Each dictionary contains the currency code, name and symbol for the currency. The code is sufficient for our data, so we will extract each code.

# %%
countries_df['currency_code'] = countries_df['currencies'].apply(
    lambda x: x[0]['code'] if isinstance(x, list) else None
)

# %% [markdown]
# <strong>Languages</strong><br>
# The languages column contains a list of dictionaries with language information. Languages can have a significant impact on song popularity, so we will split this data into two important items: 1- a count of the number of languages spoken. 2- create individual columns for each unique language and input a value of 0 if the language is not commonly spoken in the country, or 1 if it is.

# %%
countries_df['num_languages'] = countries_df['languages'].apply(
    lambda x: len(x) if isinstance(x, list) else 0
)

# %%
countries_df['language_names'] = countries_df['languages'].apply(
    lambda langs: [l['name'] for l in langs] if isinstance(langs, list) else []
)

# %%
mlb = MultiLabelBinarizer()

languages_encoded = pd.DataFrame(
    mlb.fit_transform(countries_df['language_names']),
    columns=[f"lang_{l.lower()}" for l in mlb.classes_],
    index=countries_df.index
)

# %%
countries_df = pd.concat([countries_df, languages_encoded], axis=1)

# %% [markdown]
# <strong>regionalBlocs</strong><br>
# The regionalBlocs column contains a list of dictionaries that show what Associations/Unions the country is a part of. For this data we will create individual columns for each unique bloc and input a value of 0 if the country is not a member and a 1 if they are.

# %%
countries_df["regional_blocs"] = countries_df["regionalBlocs"].apply(
    lambda blocs: [b["acronym"] for b in blocs] if isinstance(blocs, list) else []
)

# %%
mlb = MultiLabelBinarizer()

blocs_encoded = pd.DataFrame(
    mlb.fit_transform(countries_df["regional_blocs"]),
    columns=[f"bloc_{b}" for b in mlb.classes_],
    index=countries_df.index
)

countries_df = pd.concat([countries_df, blocs_encoded], axis=1)

# %%
countries_df.columns.tolist()
# Out:
# ['name',
#  'alpha2Code',
#  'alpha3Code',
#  'capital',
#  'subregion',
#  'region',
#  'population',
#  'latlng',
#  'demonym',
#  'area',
#  'gini',
#  'timezones',
#  'borders',
#  'nativeName',
#  'numericCode',
#  'currencies',
#  'languages',
#  'regionalBlocs',
#  'cioc',
#  'independent',
#  'num_timezones',
#  'num_borders',
#  'num_languages',
#  'language_names',
#  'lang_english',
#  'lang_french',
#  'lang_german',
#  'lang_japanese',
#  'lang_portuguese',
#  'lang_spanish',
#  'currency_code',
#  'regional_blocs',
#  'bloc_AU',
#  'bloc_EU',
#  'bloc_NAFTA',
#  'bloc_PA',
#  'bloc_USAN']

# %% [markdown]
# Now that this data has been cleaned and transformed these columns can be dropped:
#
# - <strong>alpha3Code</strong> - duplicate information for alpha2Code
# - <strong>timezones</strong> - replaced by num_timezones
# - <strong>borders</strong> - repalced by num_boarders
# - <strong>nativeName</strong> - duplicate information for name
# - <strong>numericCode</strong> - duplicate information for name
# - <strong>currencies</strong> - replaced by currency_code
# - <strong>languages</strong> - replaced by num_languages and individual lang columns
# - <strong>regionalBlocs</strong> - replaced by individual bloc columns
# - <strong>language_names</strong> - created as a step to create individual lang columns
# - <strong>regional_blocs</strong> - created as a step to create individual bloc columns

# %% [markdown]
# ### Additional Cleaning of Country Data

# %%
drop_cols = [
    'alpha3Code',
 'timezones',
 'borders',
 'nativeName',
 'numericCode',
 'currencies',
 'languages',
 'regionalBlocs',
 'language_names',
 'regional_blocs'
]

countries_df.drop(columns=drop_cols, inplace=True)
# Out:
# /var/folders/vn/_qrvqjjx1yb4mwjbsrg0tnj80000gn/T/ipykernel_45817/2056237762.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   countries_df.drop(columns=drop_cols, inplace=True)

# %%
countries_df
# Out:
#              name alpha2Code           capital                  subregion  \
# 0          Brazil         BR          Brasília              south america
# 1          France         FR             Paris             western europe
# 2         Germany         DE            Berlin             central europe
# 3   United States         US  Washington, D.C.           northern america
# 4       Australia         AU          Canberra  australia and new zealand
# 5  United Kingdom         GB            London            northern europe
# 6           Japan         JP             Tokyo               eastern asia
# 7          Canada         CA            Ottawa           northern america
# 8           India         IO      Diego Garcia             eastern africa
# 9          Mexico         MX       Mexico City              north america
#
#      region  population      latlng     demonym     area  gini  ...  \
# 0  americas   212559409  [-10, -55]   Brazilian  8515767  53.4  ...
# 1    europe    67391582     [46, 2]      French   640679  32.4  ...
# 2    europe    83240525     [51, 9]      German   357114  31.9  ...
# 3  americas   329484123   [38, -97]    American  9629091  41.4  ...
# 4   oceania    25687041  [-27, 133]  Australian  7692024  34.4  ...
# 5    europe    67215293    [54, -2]     British   242900  35.1  ...
# 6      asia   125836021   [36, 138]    Japanese   377930  32.9  ...
# 7  americas    38005238   [60, -95]    Canadian  9984670  33.3  ...
# 8    africa        3000  [-6, 71.5]      Indian       60  25.5  ...
# 9  americas   128932753  [23, -102]     Mexican  1964375  45.4  ...
#
#   lang_german  lang_japanese  lang_portuguese  lang_spanish  currency_code  \
# 0           0              0                1             0            BRL
# 1           0              0                0             0            EUR
# 2           1              0                0             0            EUR
# 3           0              0                0             0            USD
# 4           0              0                0             0            AUD
# 5           0              0                0             0            GBP
# 6           0              1                0             0            JPY
# 7           0              0                0             0            CAD
# 8           0              0                0             0            USD
# 9           0              0                0             1            MXN
#
#    bloc_AU  bloc_EU  bloc_NAFTA  bloc_PA  bloc_USAN
# 0        0        0           0        0          1
# 1        0        1           0        0          0
# 2        0        1           0        0          0
# 3        0        0           1        0          0
# 4        0        0           0        0          0
# 5        0        0           0        0          0
# 6        0        0           0        0          0
# 7        0        0           1        0          0
# 8        1        0           0        0          0
# 9        0        0           1        1          0
#
# [10 rows x 27 columns]

# %%
countries_df.isnull().sum()
# Out:
# name               0
# alpha2Code         0
# capital            0
# subregion          0
# region             0
# population         0
# latlng             0
# demonym            0
# area               0
# gini               0
# cioc               1
# independent        0
# num_timezones      0
# num_borders        0
# num_languages      0
# lang_english       0
# lang_french        0
# lang_german        0
# lang_japanese      0
# lang_portuguese    0
# lang_spanish       0
# currency_code      0
# bloc_AU            0
# bloc_EU            0
# bloc_NAFTA         0
# bloc_PA            0
# bloc_USAN          0
# dtype: int64

# %% [markdown]
# <strong>cioc</strong> is the only column with a missing value. This data is the country code for the National Olympic Committee. This data will not be necessary for this model so the full column will be dropped.

# %%
countries_df.drop(columns='cioc', inplace=True)
# Out:
# /var/folders/vn/_qrvqjjx1yb4mwjbsrg0tnj80000gn/T/ipykernel_45817/2733645974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   countries_df.drop(columns='cioc', inplace=True)

# %%
countries_df.isnull().sum()
# Out:
# name               0
# alpha2Code         0
# capital            0
# subregion          0
# region             0
# population         0
# latlng             0
# demonym            0
# area               0
# gini               0
# independent        0
# num_timezones      0
# num_borders        0
# num_languages      0
# lang_english       0
# lang_french        0
# lang_german        0
# lang_japanese      0
# lang_portuguese    0
# lang_spanish       0
# currency_code      0
# bloc_AU            0
# bloc_EU            0
# bloc_NAFTA         0
# bloc_PA            0
# bloc_USAN          0
# dtype: int64

# %%
countries_df.dtypes
# Out:
# name                object
# alpha2Code          object
# capital             object
# subregion           object
# region              object
# population           int64
# latlng              object
# demonym             object
# area                 int64
# gini               float64
# independent           bool
# num_timezones        int64
# num_borders          int64
# num_languages        int64
# lang_english         int64
# lang_french          int64
# lang_german          int64
# lang_japanese        int64
# lang_portuguese      int64
# lang_spanish         int64
# currency_code       object
# bloc_AU              int64
# bloc_EU              int64
# bloc_NAFTA           int64
# bloc_PA              int64
# bloc_USAN            int64
# dtype: object

# %% [markdown]
# To be clear in the EDA step, the binary columns should be converted to boolean.

# %%
binary_cols = [
    c for c in countries_df.columns
    if countries_df[c].isin([0, 1]).all()
]

countries_df[binary_cols] = countries_df[binary_cols].astype(bool)
# Out:
# /var/folders/vn/_qrvqjjx1yb4mwjbsrg0tnj80000gn/T/ipykernel_45817/3726647583.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   countries_df[binary_cols] = countries_df[binary_cols].astype(bool)

# %%
countries_df.dtypes
# Out:
# name                object
# alpha2Code          object
# capital             object
# subregion           object
# region              object
# population           int64
# latlng              object
# demonym             object
# area                 int64
# gini               float64
# independent           bool
# num_timezones        int64
# num_borders          int64
# num_languages        int64
# lang_english          bool
# lang_french           bool
# lang_german           bool
# lang_japanese         bool
# lang_portuguese       bool
# lang_spanish          bool
# currency_code       object
# bloc_AU               bool
# bloc_EU               bool
# bloc_NAFTA            bool
# bloc_PA               bool
# bloc_USAN             bool
# dtype: object

# %%
countries_df.shape
# Out:
# (10, 26)

# %% [markdown]
# ## Merge DataFrames

# %% [markdown]
# The Spotify DataFrame and Country DataFrame are now individually wrangled and cleaned, they are ready to be merged into one DataFrame. They will be merged on the Country column of

# %% [markdown]
# ### Prepare Merge

# %%
spotify_data['country'].unique().tolist()
# Out:
# ['Brazil',
#  'France',
#  'Germany',
#  'United States',
#  'Australia',
#  'United Kingdom',
#  'Japan',
#  'Canada',
#  'India',
#  'Mexico']

# %%
countries_df['name'].unique().tolist()
# Out:
# ['Brazil',
#  'France',
#  'Germany',
#  'United States',
#  'Australia',
#  'United Kingdom',
#  'Japan',
#  'Canada',
#  'India',
#  'Mexico']

# %%
countries_df.rename(columns={'name': 'country_name'}, inplace=True)
# Out:
# /var/folders/vn/_qrvqjjx1yb4mwjbsrg0tnj80000gn/T/ipykernel_45817/4178798040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   countries_df.rename(columns={'name': 'country_name'}, inplace=True)

# %%
spotify_data.rename(columns={'country': 'country_name'}, inplace=True)

# %%
spotify_data.columns.tolist()
# Out:
# ['track_id',
#  'track_name',
#  'artist_name',
#  'album_name',
#  'release_date',
#  'genre',
#  'duration_ms',
#  'popularity',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'instrumentalness',
#  'tempo',
#  'stream_count',
#  'country_name',
#  'explicit',
#  'label',
#  'duration_mm:ss:ms']

# %%
countries_df.columns.tolist()
# Out:
# ['country_name',
#  'alpha2Code',
#  'capital',
#  'subregion',
#  'region',
#  'population',
#  'latlng',
#  'demonym',
#  'area',
#  'gini',
#  'independent',
#  'num_timezones',
#  'num_borders',
#  'num_languages',
#  'lang_english',
#  'lang_french',
#  'lang_german',
#  'lang_japanese',
#  'lang_portuguese',
#  'lang_spanish',
#  'currency_code',
#  'bloc_AU',
#  'bloc_EU',
#  'bloc_NAFTA',
#  'bloc_PA',
#  'bloc_USAN']

# %% [markdown]
# ### Merge

# %%
combined_df = spotify_data.merge(
    countries_df,
    on='country_name',
    how='left'
)

# %% [markdown]
# ### Inspect Merged DataFrame

# %%
combined_df.head()
# Out:
#            track_id              track_name    artist_name         album_name  \
# 0  TRK-BEBD53DA84E1         Agent every (0)    Noah Rhodes  Beautiful instead
# 1  TRK-6A32496762D7           Night respond  Jennifer Cole              Table
# 2  TRK-47AA7523463E  Future choice whatever  Brandon Davis      Page southern
# 3  TRK-25ADA22E3B06     Bad fall pick those    Corey Jones             Spring
# 4  TRK-9245F2AD996A                 Husband      Mark Diaz        Great prove
#
#   release_date  genre  duration_ms  popularity  danceability  energy  ...  \
# 0   2016-04-01    Pop       234194          55          0.15    0.74  ...
# 1   2022-04-15  Metal       375706          45          0.44    0.46  ...
# 2   2016-02-23   Rock       289191          55          0.62    0.80  ...
# 3   2015-10-12    Pop       209484          51          0.78    0.98  ...
# 4   2022-07-08  Indie       127435          39          0.74    0.18  ...
#
#    lang_german  lang_japanese  lang_portuguese  lang_spanish  currency_code  \
# 0        False          False             True         False            BRL
# 1        False          False            False         False            EUR
# 2         True          False            False         False            EUR
# 3        False          False            False         False            EUR
# 4        False          False            False         False            USD
#
#    bloc_AU bloc_EU  bloc_NAFTA bloc_PA bloc_USAN
# 0    False   False       False   False      True
# 1    False    True       False   False     False
# 2    False    True       False   False     False
# 3    False    True       False   False     False
# 4    False   False        True   False     False
#
# [5 rows x 45 columns]

# %%
combined_df.shape
# Out:
# (84954, 45)

# %%
combined_df.isnull().sum()
# Out:
# track_id             0
# track_name           0
# artist_name          0
# album_name           0
# release_date         0
# genre                0
# duration_ms          0
# popularity           0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# instrumentalness     0
# tempo                0
# stream_count         0
# country_name         0
# explicit             0
# label                0
# duration_mm:ss:ms    0
# alpha2Code           0
# capital              0
# subregion            0
# region               0
# population           0
# latlng               0
# demonym              0
# area                 0
# gini                 0
# independent          0
# num_timezones        0
# num_borders          0
# num_languages        0
# lang_english         0
# lang_french          0
# lang_german          0
# lang_japanese        0
# lang_portuguese      0
# lang_spanish         0
# currency_code        0
# bloc_AU              0
# bloc_EU              0
# bloc_NAFTA           0
# bloc_PA              0
# bloc_USAN            0
# dtype: int64

# %%
combined_df.dtypes
# Out:
# track_id                     object
# track_name                   object
# artist_name                  object
# album_name                   object
# release_date         datetime64[ns]
# genre                        object
# duration_ms                   int64
# popularity                    int64
# danceability                float64
# energy                      float64
# key                           int64
# loudness                    float64
# mode                          int64
# instrumentalness            float64
# tempo                       float64
# stream_count                  int64
# country_name                 object
# explicit                      int64
# label                        object
# duration_mm:ss:ms            object
# alpha2Code                   object
# capital                      object
# subregion                    object
# region                       object
# population                    int64
# latlng                       object
# demonym                      object
# area                          int64
# gini                        float64
# independent                    bool
# num_timezones                 int64
# num_borders                   int64
# num_languages                 int64
# lang_english                   bool
# lang_french                    bool
# lang_german                    bool
# lang_japanese                  bool
# lang_portuguese                bool
# lang_spanish                   bool
# currency_code                object
# bloc_AU                        bool
# bloc_EU                        bool
# bloc_NAFTA                     bool
# bloc_PA                        bool
# bloc_USAN                      bool
# dtype: object

# %% [markdown]
# ### Final Data Wrangling Edits

# %% [markdown]
# Two more columns need to be converted to categorical and boolean columns for the EDA process:
# - <strong>mode</strong> - it will be more clear to see if the song is Major or Minor rather than a 0 or 1 in EDA
# - <strong>explicit</strong> - converting to boolean will be more clear in EDA

# %%
combined_df['mode'] = combined_df['mode'].map({0: 'minor', 1: 'major'})

# %%
combined_df['explicit'] = combined_df['explicit'].astype(bool)

# %%
combined_df.dtypes
# Out:
# track_id                     object
# track_name                   object
# artist_name                  object
# album_name                   object
# release_date         datetime64[ns]
# genre                        object
# duration_ms                   int64
# popularity                    int64
# danceability                float64
# energy                      float64
# key                           int64
# loudness                    float64
# mode                         object
# instrumentalness            float64
# tempo                       float64
# stream_count                  int64
# country_name                 object
# explicit                       bool
# label                        object
# duration_mm:ss:ms            object
# alpha2Code                   object
# capital                      object
# subregion                    object
# region                       object
# population                    int64
# latlng                       object
# demonym                      object
# area                          int64
# gini                        float64
# independent                    bool
# num_timezones                 int64
# num_borders                   int64
# num_languages                 int64
# lang_english                   bool
# lang_french                    bool
# lang_german                    bool
# lang_japanese                  bool
# lang_portuguese                bool
# lang_spanish                   bool
# currency_code                object
# bloc_AU                        bool
# bloc_EU                        bool
# bloc_NAFTA                     bool
# bloc_PA                        bool
# bloc_USAN                      bool
# dtype: object

# %%
combined_df['mode'].head()
# Out:
# 0    minor
# 1    minor
# 2    major
# 3    major
# 4    minor
# Name: mode, dtype: object

# %% [markdown]
# ## Data Wrangling - Conclusion

# %% [markdown]
# In the Data Wrangling phase, Spotify track data and country-level contextual data were imported, cleaned, and merged into a single master dataset (combined_df) in preparation for exploratory analysis and modeling. Each dataset was cleaned independently prior to merging, with careful attention paid to data types, missing values, redundant features, and feature relevance to the project’s predictive goal. Derived features were created where appropriate to improve interpretability during EDA, while safeguards were put in place to prevent feature leakage during modeling.
#
# Complex, nested country attributes were systematically transformed into numeric and boolean features to ensure usability, consistency, and interpretability. After cleaning, normalization, and feature engineering, the resulting dataset was structured, complete, and well-suited for exploratory analysis, enabling meaningful investigation of relationships between song characteristics, contextual factors, and popularity outcomes.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## General Exploration

# %% [markdown]
# ### All Feature Exploration

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84954 entries, 0 to 84953
# Data columns (total 45 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   track_id           84954 non-null  object
#  1   track_name         84954 non-null  object
#  2   artist_name        84954 non-null  object
#  3   album_name         84954 non-null  object
#  4   release_date       84954 non-null  datetime64[ns]
#  5   genre              84954 non-null  object
#  6   duration_ms        84954 non-null  int64
#  7   popularity         84954 non-null  int64
#  8   danceability       84954 non-null  float64
#  9   energy             84954 non-null  float64
#  10  key                84954 non-null  int64
#  11  loudness           84954 non-null  float64
#  12  mode               84954 non-null  object
#  13  instrumentalness   84954 non-null  float64
#  14  tempo              84954 non-null  float64
#  15  stream_count       84954 non-null  int64
#  16  country_name       84954 non-null  object
#  17  explicit           84954 non-null  bool
#  18  label              84954 non-null  object
#  19  duration_mm:ss:ms  84954 non-null  object
#  20  alpha2Code         84954 non-null  object
#  21  capital            84954 non-null  object
#  22  subregion          84954 non-null  object
#  23  region             84954 non-null  object
#  24  population         84954 non-null  int64
#  25  latlng             84954 non-null  object
#  26  demonym            84954 non-null  object
#  27  area               84954 non-null  int64
#  28  gini               84954 non-null  float64
#  29  independent        84954 non-null  bool
#  30  num_timezones      84954 non-null  int64
#  31  num_borders        84954 non-null  int64
#  32  num_languages      84954 non-null  int64
#  33  lang_english       84954 non-null  bool
#  34  lang_french        84954 non-null  bool
#  35  lang_german        84954 non-null  bool
#  36  lang_japanese      84954 non-null  bool
#  37  lang_portuguese    84954 non-null  bool
#  38  lang_spanish       84954 non-null  bool
#  39  currency_code      84954 non-null  object
#  40  bloc_AU            84954 non-null  bool
#  41  bloc_EU            84954 non-null  bool
#  42  bloc_NAFTA         84954 non-null  bool
#  43  bloc_PA            84954 non-null  bool
#  44  bloc_USAN          84954 non-null  bool
# dtypes: bool(13), datetime64[ns](1), float64(6), int64(9), object(16)
# memory usage: 21.8+ MB

# %%
# How many unique values does each column contain?

for col in combined_df.columns:
    unique_count = combined_df[col].astype(str).nunique()
    print(f"{col}: {unique_count}")
# Out:
# track_id: 84954
# track_name: 68915
# artist_name: 62364
# album_name: 43170
# release_date: 4018
# genre: 12
# duration_ms: 75045
# popularity: 99
# danceability: 95
# energy: 98
# key: 12
# loudness: 5401
# mode: 2
# instrumentalness: 801
# tempo: 13967
# stream_count: 2249
# country_name: 10
# explicit: 2
# label: 8
# duration_mm:ss:ms: 75045
# alpha2Code: 10
# capital: 10
# subregion: 9
# region: 5
# population: 10
# latlng: 10
# demonym: 10
# area: 10
# gini: 10
# independent: 1
# num_timezones: 8
# num_borders: 7
# num_languages: 2
# lang_english: 2
# lang_french: 2
# lang_german: 2
# lang_japanese: 2
# lang_portuguese: 2
# lang_spanish: 2
# currency_code: 8
# bloc_AU: 2
# bloc_EU: 2
# bloc_NAFTA: 2
# bloc_PA: 2
# bloc_USAN: 2

# %%
num_cols = combined_df.select_dtypes(include=np.number).columns
cat_cols = combined_df.select_dtypes(exclude=np.number).columns

# %%
combined_df[num_cols].hist(
    bins=30,
    figsize=(18, 14),
    edgecolor="black"
)

plt.tight_layout()
plt.show()

# %%
skewed_cols = ["stream_count", "population", "area"]

combined_df[skewed_cols].apply(lambda x: np.log1p(x)).hist(
    bins=30,
    figsize=(12, 6),
    edgecolor="black"
)

plt.suptitle("Log-Scaled Distributions for Skewed Numeric Features")
plt.tight_layout()
plt.show()

# %%
bool_cols = combined_df.select_dtypes(include="bool").columns

combined_df[bool_cols].sum().sort_values(ascending=False).plot(
    kind="bar",
    figsize=(12, 5)
)

plt.title("True Counts for Boolean Features")
plt.ylabel("Count")
plt.show()

# %%
for col in cat_cols:
    if combined_df[col].nunique() > 2:
        combined_df[col].value_counts().head(15).plot(
            kind="bar",
            figsize=(10, 4)
        )
        plt.title(f"Top 15 Categories in {col}")
        plt.ylabel("Count")
        plt.xticks(rotation=45)
        plt.show()

# %% [markdown]
# ### Artist Exploration

# %%
# Explore artists

artist_df = (
    combined_df
    .groupby('artist_name')
    .agg(
        num_songs=('track_id', 'count'),
        num_albums=('album_name', 'nunique'),
        mean_popularity=('popularity', 'mean'),
        median_popularity=('popularity', 'median'),
        total_streams=('stream_count', 'sum')
    )
    .reset_index()
)

# %%
artist_df.shape
# Out:
# (62364, 6)

# %%
artist_df.sort_values(by='num_songs', ascending=False).head(10)
# Out:
#                artist_name  num_songs  num_albums  mean_popularity  \
# 42794        Michael Smith         44          44        50.704545
# 42517      Michael Johnson         42          41        49.214286
# 15690          David Smith         33          33        49.939394
# 12082  Christopher Johnson         28          28        44.607143
# 12302    Christopher Smith         27          27        50.407407
# 15469        David Johnson         26          26        47.000000
# 42256        Michael Brown         26          26        46.923077
# 24699          James Smith         25          25        44.560000
# 42624       Michael Miller         24          24        45.333333
# 27989        Jessica Smith         24          24        46.833333
#
#        median_popularity  total_streams
# 42794               48.5       11585000
# 42517               49.0        3577000
# 15690               50.0         961000
# 12082               40.5         515000
# 12302               49.0        1598000
# 15469               44.5        5058000
# 42256               46.5         280000
# 24699               41.0         389000
# 42624               47.0         689000
# 27989               41.0        3381000

# %%
bins = [1, 2, 3, 5, 10, 20, 30, 40, 45]

artist_df["num_songs"].hist(bins=bins, edgecolor="black")
plt.title("Number of Songs per Artist")
plt.xlabel("Number of Songs")
plt.ylabel("Artists")
# Out:
# Text(0, 0.5, 'Artists')

# %%
bins = [1, 2, 3, 5, 10, 20, 30, 40, 45]

artist_df["num_albums"].hist(bins=bins, edgecolor="black")
plt.title("Number of Albums per Artist")
plt.xlabel("Number of Albums")
plt.ylabel("Artists")
# Out:
# Text(0, 0.5, 'Artists')

# %% [markdown]
# Interesting insight - The number of albums per artist looks identical to the number of songs per artist, indicating that the majority of songs are relased individually.

# %%
artist_df.sort_values(by='mean_popularity', ascending=False).head(30)
# Out:
#              artist_name  num_songs  num_albums  mean_popularity  \
# 46066    Nicholas Graham          1           1            100.0
# 58190        Thomas Park          1           1            100.0
# 22635       Harold Price          1           1            100.0
# 38645        Luis Waters          1           1            100.0
# 28522        Jodi Bishop          1           1            100.0
# 19472  Elizabeth Stanley          1           1            100.0
# 25095         Janet Ross          1           1            100.0
# 6646         Bobby Gomez          1           1            100.0
# 21985       Glenn Murphy          1           1            100.0
# 55217    Stanley Baldwin          1           1            100.0
# 23938     Jacob Townsend          1           1            100.0
# 35739   Kristina Roberts          1           1            100.0
# 723        Albert Harris          1           1            100.0
# 11476    Christina Munoz          1           1            100.0
# 19100     Elaine Donovan          1           1            100.0
# 49521      Renee Manning          1           1            100.0
# 42957      Micheal Riley          1           1            100.0
# 42974   Michele Anderson          1           1            100.0
# 60831    Victoria Foster          1           1            100.0
# 56617       Suzanne Reed          1           1            100.0
# 46169     Nicholas Payne          1           1            100.0
# 60619   Veronica Sellers          1           1            100.0
# 15790         Dawn Berry          1           1            100.0
# 49424       Regina Roman          1           1            100.0
# 46540     Nicole Perkins          1           1            100.0
# 58440   Tiffany Reynolds          1           1            100.0
# 38552      Lucas Summers          1           1            100.0
# 44115       Morgan Cross          1           1            100.0
# 23169      Henry Jimenez          1           1            100.0
# 40057          Mark Ryan          1           1            100.0
#
#        median_popularity  total_streams
# 46066              100.0       14458000
# 58190              100.0       20000000
# 22635              100.0       20000000
# 38645              100.0        1708000
# 28522              100.0       20000000
# 19472              100.0        8383000
# 25095              100.0        4952000
# 6646               100.0       20000000
# 21985              100.0       20000000
# 55217              100.0       20000000
# 23938              100.0       20000000
# 35739              100.0       20000000
# 723                100.0        8038000
# 11476              100.0         283000
# 19100              100.0         103000
# 49521              100.0       20000000
# 42957              100.0        7422000
# 42974              100.0        4304000
# 60831              100.0         584000
# 56617              100.0       20000000
# 46169              100.0        1746000
# 60619              100.0       20000000
# 15790              100.0        5458000
# 49424              100.0       20000000
# 46540              100.0       20000000
# 58440              100.0        4398000
# 38552              100.0        2917000
# 44115              100.0        2320000
# 23169              100.0          94000
# 40057              100.0        2350000

# %%
artist_df.sort_values(by='total_streams', ascending=False).head(30)
# Out:
#             artist_name  num_songs  num_albums  mean_popularity  \
# 4792     Anthony Walker          5           5        62.400000
# 48078        Peter Hall          3           3        71.666667
# 49081     Rebecca Brown          9           9        60.333333
# 35203    Kimberly Smith         12          12        59.750000
# 25664       Jason Owens          4           4        61.250000
# 52075  Samantha Johnson          6           6        58.500000
# 9004      Caitlin Smith          2           2        89.000000
# 55447     Stephanie Lee          6           6        70.666667
# 2086       Amanda Henry          6           6        65.666667
# 59146    Todd Rodriguez          2           2        86.500000
# 3363     Andrew Johnson          6           6        43.833333
# 26935    Jennifer Smith         23          23        52.739130
# 53221      Scott Carter          2           2        91.000000
# 56831    Tammy Anderson          2           2        83.500000
# 55310  Stephanie Castro          2           2        79.500000
# 42531      Michael King         11          11        57.636364
# 20531       Erin Howell          3           3        70.000000
# 34908   Kimberly Bowman          2           2        86.000000
# 9490        Carly Baker          2           2        88.000000
# 34310   Kenneth Schmidt          2           2        89.500000
# 30400      Joseph Lopez          4           4        59.750000
# 56205      Steven Smith         15          15        46.466667
# 11341   Christina Brown          5           5        62.800000
# 32685   Katherine Smith          7           7        54.714286
# 42403    Michael Garcia         20          20        46.550000
# 14475  Daniel Hernandez          6           6        53.166667
# 7572      Brenda Wilson          2           2        92.000000
# 36765     Lauren Morris          4           4        56.750000
# 61690    William Hughes          3           3        65.666667
# 40599      Mary Russell          7           7        61.142857
#
#        median_popularity  total_streams
# 4792                46.0       40008000
# 48078               90.0       34132000
# 49081               50.0       27892000
# 35203               57.0       26801000
# 25664               60.5       25351000
# 52075               48.5       24405000
# 9004                89.0       24327000
# 55447               73.5       24221000
# 2086                57.0       21858000
# 59146               86.5       21802000
# 3363                32.5       21664000
# 26935               51.0       21528000
# 53221               91.0       21306000
# 56831               83.5       21241000
# 55310               79.5       20984000
# 42531               50.0       20784000
# 20531               76.0       20764000
# 34908               86.0       20681000
# 9490                88.0       20525000
# 34310               89.5       20426000
# 30400               58.0       20376000
# 56205               45.0       20368000
# 11341               56.0       20313000
# 32685               56.0       20285000
# 42403               43.0       20243000
# 14475               52.0       20225000
# 7572                92.0       20220000
# 36765               53.0       20215000
# 61690               80.0       20193000
# 40599               56.0       20182000

# %% [markdown]
# An interesting insight came from exploring the Artist Data Frame. This data has a columns showing the mean and median popularity for each artist - surprisingly there are more than 30 artists with a perfect 100 popularity score for both mean and median, which also may be due to many artists having only 1 song. However, when inspecting the top 30 total streamed, none of the artists have a mean or median popularity score of 100. We need to inspect further to determine if popularity is acutually the best column to use as our target data. Stream Count could be a better primary target feature to focus on for musicians and labels.
#
# Let's inspect this information in the combined dataframe.

# %%
combined_df[['track_name', 'artist_name', 'album_name', 'popularity', 'stream_count']].sort_values(by='popularity', ascending=False).head(20)
# Out:
#                         track_name         artist_name           album_name  \
# 83048               Professor free     Kathy Mcconnell            My answer
# 2748        Front sure capital how       Marissa Green                 Yeah
# 29249    President production both      Justin Sanders            Hand huge
# 73145                   This coach         Jason Ewing         Picture them
# 38411      Day cut maintain second         John Hughes              Example
# 64723    Place resource gas camera       Pamela Graham         For military
# 71742                   Collection       Alicia Arnold                Think
# 76999                     Me thank      Jacob Townsend           Early mean
# 47497                 Relationship      Nichole Lawson              Capital
# 78057             Represent public   Christopher Jones                 West
# 8615                            Up     Rebecca Sanchez      Economy support
# 64692  Position start finish share    Kimberly Everett               People
# 51426                     Boy true         Erin Wilson       Recognize wall
# 59067                           We     Andrew Bartlett     Never difference
# 8125     Hour forward particularly    Cassie Rodriguez        Congress type
# 29266                    Nor visit   Elizabeth Stanley              Without
# 43500                  Need choice  Michael Washington           Drug board
# 67553           Simple common deep        Robert Ortiz               Across
# 39133  Attention name herself film        Morgan Cross  Marriage Republican
# 36353                     For that         Terry Parks                 Need
#
#        popularity  stream_count
# 83048         100       9150000
# 2748          100      20000000
# 29249         100       8524000
# 73145         100       4528000
# 38411         100      20000000
# 64723         100      20000000
# 71742         100       7249000
# 76999         100      20000000
# 47497         100      20000000
# 78057         100       7368000
# 8615          100      18075000
# 64692         100      20000000
# 51426         100      20000000
# 59067         100      20000000
# 8125          100      17535000
# 29266         100       8383000
# 43500         100       1555000
# 67553         100      20000000
# 39133         100       2320000
# 36353         100      20000000

# %%
combined_df[['track_name', 'artist_name', 'album_name', 'popularity', 'stream_count']].sort_values(by='stream_count', ascending=False).head(20)
# Out:
#                            track_name       artist_name        album_name  \
# 40577  Conference read you experience      Amy Shepherd        Young rule
# 60390                    Million side   Nicholas Fowler            Second
# 84283                   Recognize fly      Allison Hale       Get meeting
# 29859                          It gas      Daniel Lewis             Order
# 48812                          Camera   Stephanie Roach              Drop
# 60004                            List     Caitlin Smith            Listen
# 29697                    Only address       Manuel Yang      Hope current
# 74897                  Tend scientist    Lauren Roberts     Teacher these
# 74829                     Place piece        Tracy Pope              Yard
# 74801                 Parent of teach    Cindy Figueroa  Religious spring
# 74690              Stay take push you      Scott Carter            Pretty
# 12156      Son former six follow beat     Jessica Perez              Take
# 42807                      Son modern      Andrew Young          Together
# 29540                Position account     Jessica Clark  Military address
# 60225    Control guy start beat claim    Michael Gordon            Camera
# 60236             Often wind increase      Janet Briggs             Treat
# 74630                     Growth task      Jeremiah Cox             Learn
# 12308                       Reach let  Stephen Mitchell             Tough
# 42760             Half attorney bring    Russell Flores               Try
# 12534                 Civil same when    Alexander Hill           Success
#
#        popularity  stream_count
# 40577         100      20000000
# 60390          99      20000000
# 84283          96      20000000
# 29859          97      20000000
# 48812          93      20000000
# 60004         100      20000000
# 29697          97      20000000
# 74897          89      20000000
# 74829          87      20000000
# 74801          85      20000000
# 74690         100      20000000
# 12156          97      20000000
# 42807         100      20000000
# 29540          87      20000000
# 60225          92      20000000
# 60236          97      20000000
# 74630         100      20000000
# 12308         100      20000000
# 42760          84      20000000
# 12534          97      20000000

# %% [markdown]
# Exploring the main data set, we can see that the stream count clearly has a miximum of 20 million streams. There are more than 30 records with 20 mil streams listed, and several have a popularity score of 100, but there are also many with a maxed out stream count that do not have a perfect 100 popularity score. This tells us that number of stream counts is not the only factor taken into account to determine the popularity score, so it is still the best for our primary target feature. However stream count can still be very useful marketing and budget information for artists and labels, so it will be a strong secondary target feature.

# %% [markdown]
# ### Label Exploration

# %%
label_df = (
    combined_df
    .groupby('label')
    .agg(
        num_artists=('artist_name', 'count'),
        num_songs=('track_id', 'count'),
        num_albums=('album_name', 'nunique'),
        mean_popularity=('popularity', 'mean'),
        median_popularity=('popularity', 'median'),
        total_streams=('stream_count', 'sum')
    )
    .reset_index()
)

# %%
label_df['stream_count_rank'] = label_df['total_streams'].rank(method='min', ascending=False).astype(int)
label_df['num_artist_Rank'] = label_df['num_artists'].rank(method='min', ascending=False).astype(int)
label_df['num_songs_rank'] = label_df['num_albums'].rank(method='min', ascending=False).astype(int)
label_df['mean_pop_rank'] = label_df['mean_popularity'].rank(method='min', ascending=False).astype(int)

# %%
label_df.sort_values(by='mean_popularity', ascending=False)
# Out:
#              label  num_artists  num_songs  num_albums  mean_popularity  \
# 4       Sony Music        10620      10620        6324        48.322693
# 1              EMI        10572      10572        6376        48.307037
# 2      Independent        10763      10763        6388        48.260894
# 7    XL Recordings        10684      10684        6481        48.210876
# 5  Universal Music        10496      10496        6260        48.207508
# 0         Columbia        10685      10685        6371        48.090220
# 3   Island Records        10519      10519        6299        48.005609
# 6     Warner Music        10615      10615        6238        47.901083
#
#    median_popularity  total_streams  stream_count_rank  num_artist_Rank  \
# 4               47.0     2419227000                  2                4
# 1               47.0     2451406000                  1                6
# 2               47.0     2383638000                  3                1
# 7               47.0     2103647000                  8                3
# 5               47.0     2276440000                  4                8
# 0               46.0     2162393000                  7                2
# 3               46.0     2179477000                  6                7
# 6               46.0     2242179000                  5                5
#
#    num_songs_rank  mean_pop_rank
# 4               5              1
# 1               3              2
# 2               2              3
# 7               1              4
# 5               7              5
# 0               4              6
# 3               6              7
# 6               8              8

# %% [markdown]
# There are 8 total labels that represent all of the artists and songs in the data set. When ranking the lables on the most stream count, number of artists they represent, and number of songs, we see that there is not one label that ranks highest on all three. This indicates that there is not a dominant label that produces the most popular songs all of the time.

# %% [markdown]
# ### Song Exploration

# %%
# What are the top songs with a perfect 100 popularity score and 2 Mil Streams?

condition1 = combined_df['popularity'] == 100
condition2 = combined_df['stream_count'] == 20000000
combined_conditions = condition1 & condition2

Top_Songs = combined_df[combined_conditions]
print(f"There are {len(Top_Songs)} songs with a popularity score of 100 and 20,000,000 streams")
print(f"There are {Top_Songs['artist_name'].nunique()} artists who have at least one song with a popularity score of 100 and 20,000,000 streams")
# Out:
# There are 201 songs with a popularity score of 100 and 20,000,000 streams
# There are 201 artists who have at least one song with a popularity score of 100 and 20,000,000 streams

# %% [markdown]
# Another interesting insight from exploring the top songs - there are no artists that have more than 1 song that is the top in both popularity and stream_count. How does this compare to our full dataset?

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

combined_df.hist('popularity', bins=100, ax=axes[0])
combined_df.hist('stream_count', bins=10, ax=axes[1])

axes[0].set_title("Popularity")
axes[1].set_title("Stream Count")

plt.tight_layout()
plt.show()

# %% [markdown]
# When visualizing the distributions of <strong>Popularity</strong> and <strong>Stream Count</strong>, we see that Popularity is normally distributed with an additional spike at 100, whereas Stream Count is heavily right skewed indicating that the vast majority of songs have a stream count of less than 2.5 Million. We know the maxmimum stream count is 20 Million, so to more accurately compare the relationship between these two we need to use a logrithmic scale for stream count.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=combined_df, 
    x='popularity', 
    y='stream_count', 
    alpha=0.3,
    edgecolor=None,
    s=20
)

plt.yscale('log')
plt.title('Popularity vs. Stream Count (Scatter)')
plt.ylabel('Stream Count (Log Scale)')
plt.grid(True, which="both", ls="-", alpha=0.2)
plt.show()

# %% [markdown]
# In this scatter plot we can see the relationship between popularity and stream count shows a positive correlation as expected. We can also see some unexpected groupings showing that popularity scores of 100 have a wide range of stream counts, but do not drop below 100,000, and stream counts maxed at 20 million do not drop below popularity scores of approximately 65.

# %%
analysis_date = combined_df["release_date"].max()

combined_df["days_since_release"] = (
    analysis_date - combined_df["release_date"]
).dt.days

# %%
plt.figure(figsize=(8, 6))
plt.scatter(
    combined_df["days_since_release"],
    np.log1p(combined_df["stream_count"]),
    alpha=0.3
)
plt.xlabel("Days Since Release")
plt.ylabel("Log(Stream Count)")
plt.title("Log Stream Count vs Time Since Release")
plt.show()

# %%
combined_df["streams_per_day"] = (
    combined_df["stream_count"] / combined_df["days_since_release"].clip(lower=1)
)

# %%
combined_df[['track_name','artist_name','streams_per_day','release_date','stream_count','popularity']].sort_values(by='streams_per_day', ascending=False).head(10)
# Out:
#                                  track_name             artist_name  \
# 79818                           Light would            Glenn Murphy
# 61906                         Federal floor          Melissa Hansen
# 34631                                  Base          Anthony Walker
# 6465             Would exactly between mind            Anita Torres
# 63960                               Special          Kimberly James
# 14195  Who treat technology around response           Johnny Steele
# 79908                       Those know star        Ruben Williamson
# 76485                          Yourself act  Mr. Walter Sullivan MD
# 47532              Tell rest avoid probably         Kimberly Bowman
# 75220                   Spring support over        William Anderson
#
#        streams_per_day release_date  stream_count  popularity
# 79818     1.000000e+07   2025-12-29      20000000         100
# 61906     5.673667e+06   2025-12-28      17021000          87
# 34631     5.000000e+06   2025-12-27      20000000          92
# 6465      4.000000e+06   2025-12-26      20000000          91
# 63960     1.112600e+06   2025-12-26       5563000         100
# 14195     1.000000e+06   2025-12-11      20000000         100
# 79908     8.000000e+05   2025-12-06      20000000          88
# 76485     7.142857e+05   2025-12-03      20000000         100
# 47532     6.802500e+05   2025-12-07      16326000          96
# 75220     6.250000e+05   2025-11-29      20000000          98

# %% [markdown]
# ### Genre Exploration

# %%
combined_df['genre'].nunique()
# Out:
# 12

# %%
genre_df = (
    combined_df
    .groupby('genre')
    .agg(
        num_songs=('track_id', 'count'),
        num_artists=('artist_name', 'count'),
        num_albums=('album_name', 'nunique'),
        mean_popularity=('popularity', 'mean'),
        median_popularity=('popularity', 'median'),
        total_streams=('stream_count', 'sum')
    )
    .reset_index()
)

# %%
genre_df['num_songs_rank'] = genre_df['num_songs'].rank(method='min', ascending=False).astype(int)
genre_df['num_artists_rank'] = genre_df['num_artists'].rank(method='min', ascending=False).astype(int)
genre_df['mean_pop_rank'] = genre_df['mean_popularity'].rank(method='min', ascending=False).astype(int)
genre_df['median_pop_rank'] = genre_df['median_popularity'].rank(method='min', ascending=False).astype(int)
genre_df['total_stream_rank'] = genre_df['total_streams'].rank(method='min', ascending=False).astype(int)

# %%
genre_df.sort_values(by='mean_pop_rank', ascending=True)
# Out:
#         genre  num_songs  num_artists  num_albums  mean_popularity  \
# 8         Pop       7088         7088        4498        48.375564
# 9         R&B       7080         7080        4550        48.364972
# 0   Classical       7154         7154        4641        48.364971
# 4     Hip-Hop       7156         7156        4557        48.360257
# 2         EDM       6885         6885        4433        48.208424
# 7       Metal       7198         7198        4565        48.192276
# 1     Country       7027         7027        4462        48.170912
# 5       Indie       7001         7001        4475        48.125982
# 3        Folk       7078         7078        4493        48.096779
# 11       Rock       7110         7110        4553        47.968354
# 10  Reggaeton       7001         7001        4545        47.881446
# 6        Jazz       7176         7176        4569        47.849220
#
#     median_popularity  total_streams  num_songs_rank  num_artists_rank  \
# 8                47.0     1538132000               6                 6
# 9                47.0     1624312000               7                 7
# 0                47.0     1558455000               4                 4
# 4                47.0     1906753000               3                 3
# 2                47.0     1532953000              12                12
# 7                47.0     1604970000               1                 1
# 1                46.0     1440463000               9                 9
# 5                47.0     1257966000              10                10
# 3                47.0     1538901000               8                 8
# 11               46.0     1452050000               5                 5
# 10               46.0     1316019000              10                10
# 6                46.0     1447433000               2                 2
#
#     mean_pop_rank  total_stream_rank
# 8               1                  6
# 9               2                  2
# 0               3                  4
# 4               4                  1
# 2               5                  7
# 7               6                  3
# 1               7                 10
# 5               8                 12
# 3               9                  5
# 11             10                  8
# 10             11                 11
# 6              12                  9

# %% [markdown]
# Once again we find that the popularity score and total number of streams do not align. In the Genre Data Frame we can see that the pop genre is the most popular but is the 6th most streamed whereas the hip hop genre is the most streamed but is the 4th highest popular. While this may seem at first glance as misleading, it actually indicates that there are other features that contribute to the ultimate popularity and success of a song. When we show the data on a scatter plot (below) with the hue set to genres we can easily see that there is no visable pattern or clusters for genre, and each genre has a wide distribution of popularity and stream count.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=combined_df, 
    x='popularity', 
    y='stream_count',
    hue='genre',
    alpha=0.3,
    edgecolor=None,
    s=20
)

plt.yscale('log')
plt.title('Popularity vs. Stream Count (Scatter)')
plt.ylabel('Stream Count (Log Scale)')
plt.legend()
plt.grid(True, which="both", ls="-", alpha=0.2)
plt.show()

# %% [markdown]
# ### Region/Country

# %%
combined_df.groupby("region")["popularity"].mean().sort_values(ascending=False)
# Out:
# region
# asia        48.349959
# europe      48.276260
# americas    48.098849
# oceania     48.048287
# africa      48.008929
# Name: popularity, dtype: float64

# %%
combined_df.groupby("region")["stream_count"].mean().sort_values(ascending=False)
# Out:
# region
# asia        234572.427456
# europe      221648.559800
# americas    211246.885081
# africa      208339.285714
# oceania     191179.590866
# Name: stream_count, dtype: float64

# %%
combined_df.groupby("country_name")["popularity"].mean().sort_values(ascending=False)
# Out:
# country_name
# United Kingdom    48.409419
# Japan             48.349959
# France            48.341478
# Brazil            48.316993
# Germany           48.079326
# Canada            48.061753
# United States     48.059133
# Australia         48.048287
# India             48.008929
# Mexico            47.954884
# Name: popularity, dtype: float64

# %%
combined_df.groupby("country_name")["stream_count"].mean().sort_values(ascending=False)
# Out:
# country_name
# Japan             234572.427456
# France            230154.430676
# Mexico            227574.154068
# United Kingdom    221204.709502
# Canada            217715.264074
# Germany           213574.587575
# India             208339.285714
# Brazil            206760.900306
# United States     192845.104142
# Australia         191179.590866
# Name: stream_count, dtype: float64

# %%
combined_df.boxplot(
    column="popularity",
    by="country_name",
    rot=45,
    figsize=(10, 5)
)
# Out:
# <Axes: title={'center': 'popularity'}, xlabel='country_name'>

# %% [markdown]
# ## Correlation Analysis

# %%
num_cols
# Out:
# Index(['duration_ms', 'popularity', 'danceability', 'energy', 'key',
#        'loudness', 'instrumentalness', 'tempo', 'stream_count', 'population',
#        'area', 'gini', 'num_timezones', 'num_borders', 'num_languages'],
#       dtype='object')

# %%
cat_cols
# Out:
# Index(['track_id', 'track_name', 'artist_name', 'album_name', 'release_date',
#        'genre', 'mode', 'country_name', 'explicit', 'label',
#        'duration_mm:ss:ms', 'alpha2Code', 'capital', 'subregion', 'region',
#        'latlng', 'demonym', 'independent', 'lang_english', 'lang_french',
#        'lang_german', 'lang_japanese', 'lang_portuguese', 'lang_spanish',
#        'currency_code', 'bloc_AU', 'bloc_EU', 'bloc_NAFTA', 'bloc_PA',
#        'bloc_USAN'],
#       dtype='object')

# %% [markdown]
# ### Numerical Feature Correlation

# %%
num_cols = combined_df.select_dtypes(include=np.number).columns

# %%
num_cols
# Out:
# Index(['duration_ms', 'popularity', 'danceability', 'energy', 'key',
#        'loudness', 'instrumentalness', 'tempo', 'stream_count', 'population',
#        'area', 'gini', 'num_timezones', 'num_borders', 'num_languages',
#        'days_since_release', 'streams_per_day'],
#       dtype='object')

# %%
corr_matrix = combined_df[num_cols].corr()
corr_matrix['popularity'].sort_values(ascending=False)
# Out:
# popularity            1.000000
# stream_count          0.357563
# streams_per_day       0.040876
# loudness              0.003242
# danceability          0.003227
# num_timezones         0.003093
# num_borders           0.002845
# instrumentalness      0.002093
# gini                  0.001062
# population            0.000777
# energy               -0.000318
# duration_ms          -0.000506
# num_languages        -0.002303
# tempo                -0.002734
# area                 -0.002872
# key                  -0.003242
# days_since_release   -0.004373
# Name: popularity, dtype: float64

# %%
plt.figure(figsize=(10, 8))
plt.imshow(corr_matrix, cmap="coolwarm")
plt.colorbar()
plt.xticks(range(len(num_cols)), num_cols, rotation=90)
plt.yticks(range(len(num_cols)), num_cols)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# The Pearson corrleation analysis of numeric features shows that no single numeric feature has a strong linear relationship with track popularity, with the exception of stream count which is our other target feature. This suggests that the track popularity is not driven by simple linear effects, and is more likely influenced by non-linear interactions, aggregation-level effects, and/or possibly categorical features.

# %% [markdown]
# ### Categorical Feature Correlation

# %%
for col in cat_cols:
    if combined_df[col].apply(lambda x: isinstance(x, list)).any():
        combined_df[col] = combined_df[col].apply(tuple)

# %%
binary_cat_cols = [
    col for col in cat_cols
    if combined_df[col].nunique() == 2
]

multi_cat_cols = [
    col for col in cat_cols
    if combined_df[col].nunique() > 2
]

# %%
for col in binary_cat_cols:
    print(f"\n{col.upper()}")
    display(
        combined_df.groupby(col)["popularity"]
        .agg(["mean", "median", "count"])
        .sort_values("mean", ascending=False)
    )
# Out:
# MODE
#             mean  median  count
# mode
# minor  48.186124    47.0  42461
# major  48.140776    46.0  42493
# EXPLICIT
#                mean  median  count
# explicit
# False     48.169973    47.0  67852
# True      48.137528    47.0  17102
# LANG_ENGLISH
#                    mean  median  count
# lang_english
# False         48.209778    47.0  42502
# True          48.117050    47.0  42452
# LANG_FRENCH
#                   mean  median  count
# lang_french
# True         48.201118    46.0  17169
# False        48.153898    47.0  67785
# LANG_GERMAN
#                   mean  median  count
# lang_german
# False        48.172851    47.0  76407
# True         48.079326    46.0   8547
# LANG_JAPANESE
#                     mean  median  count
# lang_japanese
# True           48.349959    47.0   8581
# False          48.142485    47.0  76373
# LANG_PORTUGUESE
#                       mean  median  count
# lang_portuguese
# True             48.316993    47.0   8486
# False            48.146401    47.0  76468
# LANG_SPANISH
#                    mean  median  count
# lang_spanish
# False         48.186126    47.0  76620
# True          47.954884    46.0   8334
# BLOC_AU
#               mean  median  count
# bloc_AU
# False    48.180899    47.0  76330
# True     48.008929    47.0   8624
# BLOC_EU
#               mean  median  count
# bloc_EU
# True     48.210456    46.0  17101
# False    48.151592    47.0  67853
# BLOC_NAFTA
#                  mean  median  count
# bloc_NAFTA
# False       48.221874    47.0  59651
# True        48.025689    46.0  25303
# BLOC_PA
#               mean  median  count
# bloc_PA
# False    48.186126    47.0  76620
# True     47.954884    46.0   8334
# BLOC_USAN
#                 mean  median  count
# bloc_USAN
# True       48.316993    47.0   8486
# False      48.146401    47.0  76468

# %%
for col in binary_cat_cols:
    combined_df.boxplot(column="popularity", by=col)

# %%
for col in multi_cat_cols:
    print(f"\nAnalyzing: {col}")

    top_categories = (
        combined_df[col]
        .value_counts()
        .head(10)
        .index
    )

    temp_df = combined_df[combined_df[col].isin(top_categories)]

    display(
        temp_df.groupby(col)["popularity"]
        .agg(["mean", "median", "count"])
        .sort_values("mean", ascending=False)
    )

    temp_df.boxplot(column="popularity", by=col, rot=45)
# Out:
# Analyzing: track_id
#                   mean  median  count
# track_id
# TRK-BEBD53DA84E1  55.0    55.0      1
# TRK-7AAF54A5A26C  50.0    50.0      1
# TRK-B00FB3BA8500  44.0    44.0      1
# TRK-104036BD31E4  42.0    42.0      1
# TRK-3F3C8C644B93  41.0    41.0      1
# TRK-64C447ECE995  39.0    39.0      1
# TRK-D2AFBA0CAFB5  38.0    38.0      1
# TRK-D5DA316EC610  37.0    37.0      1
# TRK-723A05CA3DC3  34.0    34.0      1
# TRK-6F2BBABDF154  18.0    18.0      1
# Analyzing: track_name
#                  mean  median  count
# track_name
# Stand       53.312500    51.5     32
# Ten         52.400000    47.0     30
# Work        51.357143    49.5     28
# New         49.464286    45.5     28
# Shoulder    48.551724    47.0     29
# Fine        48.103448    49.0     29
# Expert      46.607143    45.0     28
# Somebody    46.592593    46.0     27
# A           45.000000    41.0     29
# Ball        44.444444    44.0     27
# Analyzing: artist_name
#                           mean  median  count
# artist_name
# Michael Smith        50.704545    48.5     44
# Christopher Smith    50.407407    49.0     27
# David Smith          49.939394    50.0     33
# Michael Johnson      49.214286    49.0     42
# David Johnson        47.000000    44.5     26
# Michael Brown        46.923077    46.5     26
# Jessica Smith        46.833333    41.0     24
# Michael Miller       45.333333    47.0     24
# Christopher Johnson  44.607143    40.5     28
# James Smith          44.560000    41.0     25
# Analyzing: album_name
#                  mean  median  count
# album_name
# Though      51.310345    49.5     58
# Drop        51.000000    49.0     61
# Probably    50.983051    49.0     59
# Visit       49.515625    47.0     64
# Once        48.525424    48.0     59
# Table       47.568966    48.0     58
# Movie       46.932203    46.0     59
# Develop     46.913793    47.0     58
# Theory      46.343750    46.5     64
# Simply      45.864407    43.0     59
# Analyzing: release_date
#                    mean  median  count
# release_date
# 2023-12-27    51.432432    51.0     37
# 2015-06-03    49.078947    47.5     38
# 2018-01-03    48.800000    49.0     40
# 2025-08-24    48.228571    46.0     35
# 2021-10-29    47.666667    48.0     36
# 2025-12-19    47.305556    44.0     36
# 2021-07-10    46.314286    42.0     35
# 2022-02-07    46.200000    46.0     35
# 2018-08-14    45.861111    45.5     36
# 2018-01-02    44.710526    42.0     38
# Analyzing: genre
#                 mean  median  count
# genre
# Pop        48.375564    47.0   7088
# R&B        48.364972    47.0   7080
# Classical  48.364971    47.0   7154
# Hip-Hop    48.360257    47.0   7156
# Metal      48.192276    47.0   7198
# Country    48.170912    46.0   7027
# Indie      48.125982    47.0   7001
# Folk       48.096779    47.0   7078
# Rock       47.968354    46.0   7110
# Jazz       47.849220    46.0   7176
# Analyzing: country_name
#                      mean  median  count
# country_name
# United Kingdom  48.409419    47.0   8451
# Japan           48.349959    47.0   8581
# France          48.341478    47.0   8554
# Brazil          48.316993    47.0   8486
# Germany         48.079326    46.0   8547
# Canada          48.061753    46.0   8615
# United States   48.059133    47.0   8354
# Australia       48.048287    47.0   8408
# India           48.008929    47.0   8624
# Mexico          47.954884    46.0   8334
# Analyzing: label
#                       mean  median  count
# label
# Sony Music       48.322693    47.0  10620
# EMI              48.307037    47.0  10572
# Independent      48.260894    47.0  10763
# XL Recordings    48.210876    47.0  10684
# Universal Music  48.207508    47.0  10496
# Columbia         48.090220    46.0  10685
# Island Records   48.005609    46.0  10519
# Warner Music     47.901083    46.0  10615
# Analyzing: duration_mm:ss:ms
#                     mean  median  count
# duration_mm:ss:ms
# 06:41:683          54.00    54.5      4
# 03:51:552          53.80    39.0      5
# 03:43:851          53.00    53.5      4
# 04:55:742          52.20    53.0      5
# 05:24:285          49.75    52.0      4
# 06:20:397          47.75    43.5      4
# 05:25:46           46.75    51.5      4
# 01:57:592          44.00    44.5      4
# 04:58:958          40.75    36.5      4
# 02:34:92           40.00    38.5      4
# Analyzing: alpha2Code
#                  mean  median  count
# alpha2Code
# GB          48.409419    47.0   8451
# JP          48.349959    47.0   8581
# FR          48.341478    47.0   8554
# BR          48.316993    47.0   8486
# DE          48.079326    46.0   8547
# CA          48.061753    46.0   8615
# US          48.059133    47.0   8354
# AU          48.048287    47.0   8408
# IO          48.008929    47.0   8624
# MX          47.954884    46.0   8334
# Analyzing: capital
#                        mean  median  count
# capital
# London            48.409419    47.0   8451
# Tokyo             48.349959    47.0   8581
# Paris             48.341478    47.0   8554
# Brasília          48.316993    47.0   8486
# Berlin            48.079326    46.0   8547
# Ottawa            48.061753    46.0   8615
# Washington, D.C.  48.059133    47.0   8354
# Canberra          48.048287    47.0   8408
# Diego Garcia      48.008929    47.0   8624
# Mexico City       47.954884    46.0   8334
# Analyzing: subregion
#                                 mean  median  count
# subregion
# northern europe            48.409419    47.0   8451
# eastern asia               48.349959    47.0   8581
# western europe             48.341478    47.0   8554
# south america              48.316993    47.0   8486
# central europe             48.079326    46.0   8547
# northern america           48.060463    47.0  16969
# australia and new zealand  48.048287    47.0   8408
# eastern africa             48.008929    47.0   8624
# north america              47.954884    46.0   8334
# Analyzing: region
#                mean  median  count
# region
# asia      48.349959    47.0   8581
# europe    48.276260    47.0  25552
# americas  48.098849    47.0  33789
# oceania   48.048287    47.0   8408
# africa    48.008929    47.0   8624
# Analyzing: latlng
#                  mean  median  count
# latlng
# (54, -2)    48.409419    47.0   8451
# (36, 138)   48.349959    47.0   8581
# (46, 2)     48.341478    47.0   8554
# (-10, -55)  48.316993    47.0   8486
# (51, 9)     48.079326    46.0   8547
# (60, -95)   48.061753    46.0   8615
# (38, -97)   48.059133    47.0   8354
# (-27, 133)  48.048287    47.0   8408
# (-6, 71.5)  48.008929    47.0   8624
# (23, -102)  47.954884    46.0   8334
# Analyzing: demonym
#                  mean  median  count
# demonym
# British     48.409419    47.0   8451
# Japanese    48.349959    47.0   8581
# French      48.341478    47.0   8554
# Brazilian   48.316993    47.0   8486
# German      48.079326    46.0   8547
# Canadian    48.061753    46.0   8615
# American    48.059133    47.0   8354
# Australian  48.048287    47.0   8408
# Indian      48.008929    47.0   8624
# Mexican     47.954884    46.0   8334
# Analyzing: currency_code
#                     mean  median  count
# currency_code
# GBP            48.409419    47.0   8451
# JPY            48.349959    47.0   8581
# BRL            48.316993    47.0   8486
# EUR            48.210456    46.0  17101
# CAD            48.061753    46.0   8615
# AUD            48.048287    47.0   8408
# USD            48.033632    47.0  16978
# MXN            47.954884    46.0   8334

# %% [markdown]
# ## EDA Conclusion

# %% [markdown]
# During the Exploratory Data Analysis phase, both numerical and categorical features were examined to understand their distributions, relationships, and potential influence on track popularity. Initial distributional analysis revealed a diverse and well-balanced dataset across core audio features, while stream count exhibited strong right skew consistent with real-world listening behavior. Deeper feature-level exploration showed that popularity is not driven by a single dominant factor, but rather reflects a combination of artist-level, genre-level, temporal, and regional influences.
#
# Correlation analysis across numeric and categorical features further supported this finding, indicating that popularity does not exhibit strong linear relationships with individual features. Instead, the results suggest that popularity is shaped by non-linear effects and interactions among multiple variables. Based on these findings, all features were retained for preprocessing and modeling to allow downstream models to capture complex relationships that are not apparent through univariate or linear analysis alone.
